# %%
import os
import requests
import pandas as pd
from dotenv import load_dotenv

# %%
load_dotenv("../client/.env.local")
# Out:
# True

# %%
scanr_url = "https://cluster-production.elasticsearch.dataesr.ovh/scanr-publications/_search"
scanr_key = f'Basic {os.getenv("VITE_API_KEY")}'
scanr_headers = {"Authorization": scanr_key}


def scanr_ipcc(agg: str):

    body = {
        "size": 0,
        "query": {
            "bool": {
                "must": [{"term": {"predict_teds.label.keyword": "ipcc"}}],
            },
        },
        "aggs": {
            f"{agg}": {
                "terms": {"field": f"{agg}.keyword", "size": 2000},
            },
        },
    }

    res = requests.post(scanr_url, json=body, headers=scanr_headers)
    if res.status_code == 200:
        return res.json()
    else:
        print(f"error {res.status_code}: {res.reason}")
        print(res.text)
        return None

# %%
res = scanr_ipcc("co_authors")
co_authors = res.get("aggregations").get("co_authors").get("buckets")

# %%
links = []
for link in co_authors:
    source = link["key"].split("---")[0].split("###")[1]
    target = link["key"].split("---")[1].split("###")[1]
    links.append({"source_id": source, "target_id": target, "strength": link["doc_count"]})


links
# Out:
# [{'source_id': 'Matthieu Lengaigne',
#   'target_id': 'Jérôme Vialard',
#   'strength': 65},
#  {'source_id': 'Philippe Ciais',
#   'target_id': 'Frédéric Chevallier',
#   'strength': 62},
#  {'source_id': 'Henri Weimerskirch',
#   'target_id': 'Christophe Barbraud',
#   'strength': 54},
#  {'source_id': 'Yann H. Kerr',
#   'target_id': 'Jean-Pierre Wigneron',
#   'strength': 54},
#  {'source_id': 'Daniel Schertzer',
#   'target_id': 'Auguste Gires',
#   'strength': 46},
#  {'source_id': 'Philippe Ciais', 'target_id': 'Nicolas Viovy', 'strength': 46},
#  {'source_id': 'Jean-Claude Dauvin',
#   'target_id': 'Jean-Philippe Pezy',
#   'strength': 45},
#  {'source_id': 'Yann H. Kerr', 'target_id': 'Arnaud Mialon', 'strength': 45},
#  {'source_id': 'Cathy Clerbaux',
#   'target_id': 'Martin Van Damme',
#   'strength': 40},
#  {'source_id': 'Jean-Luc Dupuy',
#   'target_id': 'François Pimont',
#   'strength': 38},
#  {'source_id': 'Philippe Ciais', 'target_id': 'Ana Bastos', 'strength': 36},
#  {'source_id': 'Serge Hercberg',
#   'target_id': 'Emmanuelle Kesse-Guyot',
#   'strength': 35},
#  {'source_id': 'Jean-Pierre Wigneron',
#   'target_id': 'Arnaud Mialon',
#   'strength': 33},
#  {'source_id': 'Philippe Ciais', 'target_id': 'Jinfeng Chang', 'strength': 33},
#  {'source_id': 'Philippe Ciais',
#   'target_id': 'Philippe Peylin',
#   'strength': 33},
#  {'source_id': 'Philippe Ciais',
#   'target_id': 'Frédéric Chevallier',
#   'strength': 33},
#  {'source_id': 'Laurent Bopp', 'target_id': 'Olivier Aumont', 'strength': 32},
#  {'source_id': 'Jean-Claude Dauvin',
#   'target_id': 'Aurore Raoux',
#   'strength': 31},
#  {'source_id': 'Amaëlle Landais',
#   'target_id': 'Valérie Masson-Delmotte',
#   'strength': 31},
#  {'source_id': 'Cathy Clerbaux',
#   'target_id': 'Sarah Safieddine',
#   'strength': 31},
#  {'source_id': 'Serge Hercberg',
#   'target_id': 'Benjamin Alles',
#   'strength': 30},
#  {'source_id': 'Juliette Mignot',
#   'target_id': 'Didier Swingedouw',
#   'strength': 30},
#  {'source_id': 'Philippe Ciais', 'target_id': 'Yilong Wang', 'strength': 30},
#  {'source_id': 'Patrick Chazette',
#   'target_id': 'Julien Totems',
#   'strength': 29},
#  {'source_id': 'Philippe Ciais', 'target_id': 'Glenn Peters', 'strength': 29},
#  {'source_id': 'Philip Deline',
#   'target_id': 'Ludovic Ravanel',
#   'strength': 29},
#  {'source_id': 'Sébastien Joannin',
#   'target_id': 'Odile Peyron',
#   'strength': 29},
#  {'source_id': 'Pascal Yiou', 'target_id': 'Davide Faranda', 'strength': 29},
#  {'source_id': 'Benjamin Alles',
#   'target_id': 'Emmanuelle Kesse-Guyot',
#   'strength': 29},
#  {'source_id': 'Philippe Ciais', 'target_id': 'Chao Yue', 'strength': 28},
#  {'source_id': 'Philippe Ciais',
#   'target_id': 'Daniel S. Goll',
#   'strength': 28},
#  {'source_id': 'Kathy Law',
#   'target_id': 'Jean-Christophe Raut',
#   'strength': 28},
#  {'source_id': 'Emmanuelle Kesse-Guyot',
#   'target_id': 'Julia Baudry',
#   'strength': 28},
#  {'source_id': 'Franck Lefèvre',
#   'target_id': 'Franck Montmessin',
#   'strength': 27},
#  {'source_id': 'Philippe Ciais',
#   'target_id': 'Nicolas Vuichard',
#   'strength': 27},
#  {'source_id': 'Philippe Ciais',
#   'target_id': 'Bertrand Guenet',
#   'strength': 27},
#  {'source_id': 'Philippe Ciais',
#   'target_id': 'Michel Ramonet',
#   'strength': 27},
#  {'source_id': 'Alexis Joly', 'target_id': 'Pierre Bonnet', 'strength': 27},
#  {'source_id': 'Glenn Peters',
#   'target_id': 'Corinne Le Quéré',
#   'strength': 27},
#  {'source_id': 'Frédéric Bertucci',
#   'target_id': 'David Lecchini',
#   'strength': 27},
#  {'source_id': 'Serge Hercberg', 'target_id': 'Julia Baudry', 'strength': 26},
#  {'source_id': 'François Forget',
#   'target_id': 'Aymeric Spiga',
#   'strength': 26},
#  {'source_id': 'Laurent Li', 'target_id': 'Philippe Ciais', 'strength': 26},
#  {'source_id': 'Sylvain Delzon', 'target_id': 'Hervé Cochard', 'strength': 26},
#  {'source_id': 'Bruno Castelle',
#   'target_id': 'Vincent Marieu',
#   'strength': 26},
#  {'source_id': 'Philippe Ciais',
#   'target_id': 'Grégoire Broquet',
#   'strength': 26},
#  {'source_id': 'Franck Courchamp',
#   'target_id': 'Christophe Diagne',
#   'strength': 26},
#  {'source_id': 'Anne Petrenko',
#   'target_id': 'Andrea Doglioli',
#   'strength': 26},
#  {'source_id': 'Benjamin Alles', 'target_id': 'Julia Baudry', 'strength': 26},
#  {'source_id': 'Jérémy Rohmer', 'target_id': 'Deborah Idier', 'strength': 26},
#  {'source_id': 'François Forget',
#   'target_id': 'Millour Ehouarn',
#   'strength': 25},
#  {'source_id': 'Philippe Ciais',
#   'target_id': 'Pierre Friedlingstein',
#   'strength': 25},
#  {'source_id': 'Mathieu Vrac', 'target_id': 'Pascal Yiou', 'strength': 24},
#  {'source_id': 'Fabien Arnaud',
#   'target_id': 'Pierre Sabatier',
#   'strength': 24},
#  {'source_id': 'Jean-Philippe Vidal',
#   'target_id': 'Éric Sauquet',
#   'strength': 24},
#  {'source_id': 'Patrick Chazette',
#   'target_id': 'Cyrille Flamant',
#   'strength': 24},
#  {'source_id': 'Philippe Ciais',
#   'target_id': 'Fabienne Maignan',
#   'strength': 24},
#  {'source_id': 'Philippe Ciais', 'target_id': 'Wei Li', 'strength': 24},
#  {'source_id': 'Nicole Darmon',
#   'target_id': 'Marlène Perignon',
#   'strength': 24},
#  {'source_id': 'David Grémillet', 'target_id': 'Jérôme Fort', 'strength': 24},
#  {'source_id': 'Sylvain Mailler',
#   'target_id': 'Laurent Menut',
#   'strength': 24},
#  {'source_id': 'Jérémy Rohmer',
#   'target_id': 'Gonéri Le Cozannet',
#   'strength': 24},
#  {'source_id': 'Gonéri Le Cozannet',
#   'target_id': 'Deborah Idier',
#   'strength': 24},
#  {'source_id': 'Aurore Raoux',
#   'target_id': 'Jean-Philippe Pezy',
#   'strength': 24},
#  {'source_id': 'Olivier Boucher',
#   'target_id': 'Philippe Ciais',
#   'strength': 23},
#  {'source_id': 'Thierry Thibaut',
#   'target_id': 'Aurélie Blanfuné',
#   'strength': 23},
#  {'source_id': 'Jean-Pierre Wigneron',
#   'target_id': 'Philippe Ciais',
#   'strength': 23},
#  {'source_id': 'Glenn Peters', 'target_id': 'Rob Jackson', 'strength': 23},
#  {'source_id': 'Laurent Arnaud',
#   'target_id': 'Ghislain Picard',
#   'strength': 22},
#  {'source_id': 'Charles-François Boudouresque',
#   'target_id': 'Thierry Thibaut',
#   'strength': 22},
#  {'source_id': 'Bernard Legras',
#   'target_id': 'Pasquale Sellitto',
#   'strength': 22},
#  {'source_id': 'Jean-François Doussin',
#   'target_id': 'Paola Formenti',
#   'strength': 22},
#  {'source_id': 'Paulo Eduardo Artaxo Netto',
#   'target_id': 'Joel Brito',
#   'strength': 22},
#  {'source_id': 'Philippe Ciais',
#   'target_id': 'Pierre Friedlingstein',
#   'strength': 22},
#  {'source_id': 'Hervé Cochard', 'target_id': 'Eric Badel', 'strength': 22},
#  {'source_id': 'François Pimont',
#   'target_id': 'Julien Ruffault',
#   'strength': 22},
#  {'source_id': 'Aymeric Spiga',
#   'target_id': 'Millour Ehouarn',
#   'strength': 22},
#  {'source_id': 'Glenn Peters',
#   'target_id': 'Pierre Friedlingstein',
#   'strength': 22},
#  {'source_id': 'Christophe Morhange',
#   'target_id': 'Nick Marriner',
#   'strength': 21},
#  {'source_id': 'Laurent Bopp', 'target_id': 'Marion Gehlen', 'strength': 21},
#  {'source_id': 'Philippe Ciais', 'target_id': 'Dan Zhu', 'strength': 21},
#  {'source_id': 'Hélène Hegaret',
#   'target_id': 'Philippe Soudant',
#   'strength': 21},
#  {'source_id': 'Laurent Arnaud',
#   'target_id': 'Ghislain Picard',
#   'strength': 20},
#  {'source_id': 'Jean-Luc Dupuy',
#   'target_id': 'Julien Ruffault',
#   'strength': 20},
#  {'source_id': 'Virginie Duvat',
#   'target_id': 'Alexandre Magnan',
#   'strength': 20},
#  {'source_id': 'Gilles Reverdin',
#   'target_id': 'Jacqueline Boutin',
#   'strength': 20},
#  {'source_id': 'Jérôme Demarty',
#   'target_id': 'Bernard Cappelaere',
#   'strength': 20},
#  {'source_id': 'François Forget',
#   'target_id': 'Franck Montmessin',
#   'strength': 20},
#  {'source_id': 'Bernard Barnier',
#   'target_id': 'Thierry Penduff',
#   'strength': 20},
#  {'source_id': 'Wilfried Thuiller',
#   'target_id': 'Tamara Munkemuller',
#   'strength': 20},
#  {'source_id': 'Sophie Bastin',
#   'target_id': 'Philippe Drobinski',
#   'strength': 20},
#  {'source_id': 'Juliette Mignot',
#   'target_id': 'Eric Guilyardi',
#   'strength': 20},
#  {'source_id': 'Hervé Jactel',
#   'target_id': 'Bastien Castagneyrol',
#   'strength': 20},
#  {'source_id': 'Thierry Penduff',
#   'target_id': 'Jean-Marc Molines',
#   'strength': 20},
#  {'source_id': 'Markku Kulmala', 'target_id': 'Tuukka Petäjä', 'strength': 20},
#  {'source_id': 'Charles-François Boudouresque',
#   'target_id': 'Marc Verlaque',
#   'strength': 19},
#  {'source_id': 'Sabine Simeoni-Sauvage',
#   'target_id': 'José Miguel Sanchez-Pérez',
#   'strength': 19},
#  {'source_id': 'Laurent Bopp', 'target_id': 'Roland Séférian', 'strength': 19},
#  {'source_id': 'Laurent Bopp',
#   'target_id': 'Corinne Le Quéré',
#   'strength': 19},
#  {'source_id': 'Philippe Ciais',
#   'target_id': 'Yves Balkanski',
#   'strength': 19},
#  {'source_id': 'Philippe Ciais',
#   'target_id': 'Corinne Le Quéré',
#   'strength': 19},
#  {'source_id': 'Bertrand Decharme',
#   'target_id': 'Christine Delire',
#   'strength': 19},
#  {'source_id': 'Nicolas Gruber',
#   'target_id': 'Peter Landschützer',
#   'strength': 19},
#  {'source_id': 'Glenn Peters',
#   'target_id': 'Frédéric Chevallier',
#   'strength': 19},
#  {'source_id': 'Manfred Wendisch',
#   'target_id': 'André Ehrlich',
#   'strength': 19},
#  {'source_id': 'Charles-François Boudouresque',
#   'target_id': 'Aurélie Blanfuné',
#   'strength': 18},
#  {'source_id': 'Yves Cherel', 'target_id': 'Paco Bustamante', 'strength': 18},
#  {'source_id': 'Manuel Garcin',
#   'target_id': 'Gonéri Le Cozannet',
#   'strength': 18},
#  {'source_id': 'Hervé Quenol',
#   'target_id': 'Etienne Neethling',
#   'strength': 18},
#  {'source_id': 'Vazken Andréassian',
#   'target_id': 'Charles Perrin',
#   'strength': 18},
#  {'source_id': 'Nadia Maïzi', 'target_id': 'Sandrine Selosse', 'strength': 18},
#  {'source_id': 'Jean-Pierre Chaboureau',
#   'target_id': 'Cyrille Flamant',
#   'strength': 18},
#  {'source_id': 'Nathalie Niquil', 'target_id': 'Aurore Raoux', 'strength': 18},
#  {'source_id': 'Kathy Law', 'target_id': 'Jennie L. Thomas', 'strength': 18},
#  {'source_id': 'Jean-Christophe Raut',
#   'target_id': 'Jennie L. Thomas',
#   'strength': 18},
#  {'source_id': 'Damien Bonal', 'target_id': 'Clément Stahl', 'strength': 18},
#  {'source_id': 'Ludovic Ravanel',
#   'target_id': 'Florence Magnin',
#   'strength': 18},
#  {'source_id': 'Florie Giacona',
#   'target_id': 'Nicolas Eckert',
#   'strength': 18},
#  {'source_id': 'Catherine Prigent',
#   'target_id': 'Filipe Aires',
#   'strength': 17},
#  {'source_id': 'Emmanuel Trouvé', 'target_id': 'Yajing Yan', 'strength': 17},
#  {'source_id': 'Laurent Bopp', 'target_id': 'Philippe Ciais', 'strength': 17},
#  {'source_id': 'Laurent Bopp', 'target_id': 'Glenn Peters', 'strength': 17},
#  {'source_id': 'Guillaume Decocq',
#   'target_id': 'Jonathan Lenoir',
#   'strength': 17},
#  {'source_id': 'Laurent Chauvaud',
#   'target_id': 'Julien Thébault',
#   'strength': 17},
#  {'source_id': 'Meinrat O. Andreae',
#   'target_id': 'Paulo Eduardo Artaxo Netto',
#   'strength': 17},
#  {'source_id': 'François-Marie Bréon',
#   'target_id': 'Philippe Ciais',
#   'strength': 17},
#  {'source_id': 'Philippe Ciais',
#   'target_id': 'David Makowski',
#   'strength': 17},
#  {'source_id': 'Philippe Ciais', 'target_id': 'Sönke Zaehle', 'strength': 17},
#  {'source_id': 'Isabelle Pison',
#   'target_id': 'Antoine Berchet',
#   'strength': 17},
#  {'source_id': 'Ghozlane Fleury-Bahi',
#   'target_id': 'Oscar Eduardo Navarro Carrascal',
#   'strength': 17},
#  {'source_id': 'Cyrille Flamant',
#   'target_id': 'Paola Formenti',
#   'strength': 17},
#  {'source_id': 'Cyrille Flamant',
#   'target_id': 'Marco Gaetani',
#   'strength': 17},
#  {'source_id': 'Pierre Friedlingstein',
#   'target_id': 'Frédéric Chevallier',
#   'strength': 17},
#  {'source_id': 'Frédéric Chevallier',
#   'target_id': 'Wouter Peters',
#   'strength': 17},
#  {'source_id': 'Frédéric Jean',
#   'target_id': 'Jonathan Flye-Sainte-Marie',
#   'strength': 17},
#  {'source_id': 'Oleg Dubovik', 'target_id': 'Cheng Chen', 'strength': 17},
#  {'source_id': 'Jonathan Lenoir',
#   'target_id': 'Kris Verheyen',
#   'strength': 17},
#  {'source_id': 'Jean-Pierre Gattuso',
#   'target_id': 'Frédéric Gazeau',
#   'strength': 16},
#  {'source_id': 'Bertrand Chapron',
#   'target_id': 'Alexis Mouche',
#   'strength': 16},
#  {'source_id': 'Jérôme Chave', 'target_id': 'Philippe Ciais', 'strength': 16},
#  {'source_id': 'Vincent Favier',
#   'target_id': 'Vincent Jomelli',
#   'strength': 16},
#  {'source_id': 'Guillaume Decocq',
#   'target_id': 'Kris Verheyen',
#   'strength': 16},
#  {'source_id': 'Claude Frankignoul',
#   'target_id': 'Guillaume Gastineau',
#   'strength': 16},
#  {'source_id': 'Jean-Marc Touzard',
#   'target_id': 'Nathalie Ollat',
#   'strength': 16},
#  {'source_id': 'Matthieu Lengaigne',
#   'target_id': 'Eric Guilyardi',
#   'strength': 16},
#  {'source_id': 'Gilles Bergametti',
#   'target_id': 'Béatrice Marticorena',
#   'strength': 16},
#  {'source_id': 'Laurent Chauvaud',
#   'target_id': 'Frédéric Olivier',
#   'strength': 16},
#  {'source_id': 'Philippe Ciais', 'target_id': 'Wouter Peters', 'strength': 16},
#  {'source_id': 'Philippe Ciais', 'target_id': 'Ana Bastos', 'strength': 16},
#  {'source_id': 'Patrick Lambert',
#   'target_id': 'Géraldine Lassalle',
#   'strength': 16},
#  {'source_id': 'Franck Montmessin',
#   'target_id': 'Aymeric Spiga',
#   'strength': 16},
#  {'source_id': 'Franck Montmessin',
#   'target_id': 'Millour Ehouarn',
#   'strength': 16},
#  {'source_id': 'Yves Richard', 'target_id': 'Thierry Castel', 'strength': 16},
#  {'source_id': 'Gilles Boulet', 'target_id': 'Albert Olioso', 'strength': 16},
#  {'source_id': 'Hélène Tabouret',
#   'target_id': 'Christophe Pecheyran',
#   'strength': 16},
#  {'source_id': 'Jean-Louis Rajot',
#   'target_id': 'Béatrice Marticorena',
#   'strength': 16},
#  {'source_id': 'Corinne Le Quéré',
#   'target_id': 'Frédéric Chevallier',
#   'strength': 16},
#  {'source_id': 'Corinne Le Quéré', 'target_id': 'Rob Jackson', 'strength': 16},
#  {'source_id': 'Laurent Menut',
#   'target_id': 'Bertrand Bessagnet',
#   'strength': 16},
#  {'source_id': 'Mathieu Morlighem',
#   'target_id': 'Hélène Seroussi',
#   'strength': 16},
#  {'source_id': 'Hayo Van der Werf',
#   'target_id': 'Michaël Corson',
#   'strength': 16},
#  {'source_id': 'Paola Formenti',
#   'target_id': 'Claudia Di Biagio',
#   'strength': 16},
#  {'source_id': 'Alain Dubois', 'target_id': 'Annemarie Ohler', 'strength': 15},
#  {'source_id': 'Marc Verlaque',
#   'target_id': 'Thierry Thibaut',
#   'strength': 15},
#  {'source_id': 'Slimane Bekki',
#   'target_id': 'Marion Marchand',
#   'strength': 15},
#  {'source_id': 'Cornelis Van Leeuwen',
#   'target_id': 'Hervé Quenol',
#   'strength': 15},
#  {'source_id': 'Benoît Laignel', 'target_id': 'Imen Turki', 'strength': 15},
#  {'source_id': 'Lucien Wald', 'target_id': 'Philippe Blanc', 'strength': 15},
#  {'source_id': 'Alexia Stokes', 'target_id': 'Zhun Mao', 'strength': 15},
#  {'source_id': 'Hilaire Drouineau',
#   'target_id': 'Patrick Lambert',
#   'strength': 15},
#  {'source_id': 'Yannick Donnadieu',
#   'target_id': 'Guillaume Le Hir',
#   'strength': 15},
#  {'source_id': 'Jean-Marc Fromentin',
#   'target_id': 'Claire Saraux',
#   'strength': 15},
#  {'source_id': 'Sylvain Delzon',
#   'target_id': 'José Manuel Torres-Ruiz',
#   'strength': 15},
#  {'source_id': 'Catherine Fernandez',
#   'target_id': 'Virginie Baldy',
#   'strength': 15},
#  {'source_id': 'Jean-François Doussin',
#   'target_id': 'Mathieu Cazaunau',
#   'strength': 15},
#  {'source_id': 'Philippe Ciais',
#   'target_id': 'Gerhard Krinner',
#   'strength': 15},
#  {'source_id': 'Philippe Ciais',
#   'target_id': 'Agnès Ducharne',
#   'strength': 15},
#  {'source_id': 'Philippe Ciais', 'target_id': 'Ana Bastos', 'strength': 15},
#  {'source_id': 'Philippe Ciais',
#   'target_id': 'Ronny Lauerwald',
#   'strength': 15},
#  {'source_id': 'Franck Montmessin',
#   'target_id': 'Jean-Yves Chaufray',
#   'strength': 15},
#  {'source_id': 'Franck Montmessin',
#   'target_id': 'Anni Maattanen',
#   'strength': 15},
#  {'source_id': 'Bertrand Decharme',
#   'target_id': 'Aaron Boone',
#   'strength': 15},
#  {'source_id': 'Paco Bustamante', 'target_id': 'Jérôme Fort', 'strength': 15},
#  {'source_id': 'Cécile Guieu',
#   'target_id': 'Karine Desboeufs',
#   'strength': 15},
#  {'source_id': 'Cécile Guieu', 'target_id': 'Céline Ridame', 'strength': 15},
#  {'source_id': 'Charles Perrin',
#   'target_id': 'Guillaume Thirel',
#   'strength': 15},
#  {'source_id': 'Yves Richard', 'target_id': 'Benjamin Pohl', 'strength': 15},
#  {'source_id': 'Grégoire Broquet',
#   'target_id': 'Frédéric Chevallier',
#   'strength': 15},
#  {'source_id': 'Christophe Corona',
#   'target_id': 'Nicolas Eckert',
#   'strength': 15},
#  {'source_id': 'Aymeric Spiga', 'target_id': 'Anni Maattanen', 'strength': 15},
#  {'source_id': 'Samuel Morin', 'target_id': 'Nicolas Eckert', 'strength': 15},
#  {'source_id': 'Corinne Le Quéré',
#   'target_id': 'Peter Landschützer',
#   'strength': 15},
#  {'source_id': 'Fabienne Maignan',
#   'target_id': 'Philippe Peylin',
#   'strength': 15},
#  {'source_id': 'Frédéric Chevallier',
#   'target_id': 'Philippe Peylin',
#   'strength': 15},
#  {'source_id': 'Philippe Soudant',
#   'target_id': 'Christophe Lambert',
#   'strength': 15},
#  {'source_id': 'Hélène Fouillet',
#   'target_id': 'François Mariotti',
#   'strength': 15},
#  {'source_id': 'Guillemette Menot',
#   'target_id': 'Odile Peyron',
#   'strength': 15},
#  {'source_id': 'Charles Amory',
#   'target_id': 'Xavier Fettweis',
#   'strength': 15},
#  {'source_id': 'Serge Hercberg',
#   'target_id': 'Philippe Pointereau',
#   'strength': 14},
#  {'source_id': 'Serge Hercberg',
#   'target_id': 'Sandrine Peneau',
#   'strength': 14},
#  {'source_id': 'Mireille Harmelin-Vivien',
#   'target_id': 'Sandrine Ruitton',
#   'strength': 14},
#  {'source_id': 'Jean-Claude Dauvin',
#   'target_id': 'Nathalie Niquil',
#   'strength': 14},
#  {'source_id': 'Slimane Bekki',
#   'target_id': 'Mustapha Meftah',
#   'strength': 14},
#  {'source_id': 'Didier Bourlès',
#   'target_id': 'Georges Aumaître',
#   'strength': 14},
#  {'source_id': 'Philippe Pointereau',
#   'target_id': 'Benjamin Alles',
#   'strength': 14},
#  {'source_id': 'Philippe Pointereau',
#   'target_id': 'Emmanuelle Kesse-Guyot',
#   'strength': 14},
#  {'source_id': 'Philippe Pointereau',
#   'target_id': 'Julia Baudry',
#   'strength': 14},
#  {'source_id': 'Cornelis Van Leeuwen',
#   'target_id': 'Nathalie Ollat',
#   'strength': 14},
#  {'source_id': 'Gil Mahé',
#   'target_id': 'Jean-Emmanuel Paturel',
#   'strength': 14},
#  {'source_id': 'Vincent Dubreuil',
#   'target_id': 'Damien Arvor',
#   'strength': 14},
#  {'source_id': 'Laurent Bopp',
#   'target_id': 'Frédéric Chevallier',
#   'strength': 14},
#  {'source_id': 'Grégory Beaugrand',
#   'target_id': 'Eric Goberville',
#   'strength': 14},
#  {'source_id': 'Christophe Guinet',
#   'target_id': 'Mark Hindell',
#   'strength': 14},
#  {'source_id': 'Ghislain Picard', 'target_id': 'Marie Dumont', 'strength': 14},
#  {'source_id': 'Ghislain Picard', 'target_id': 'Marie Dumont', 'strength': 14},
#  {'source_id': 'Jacques Pelon',
#   'target_id': 'Gérard Ancellet',
#   'strength': 14},
#  {'source_id': 'Pierre Testor',
#   'target_id': 'Laurent Mortier',
#   'strength': 14},
#  {'source_id': 'François Forget',
#   'target_id': 'Anni Maattanen',
#   'strength': 14},
#  {'source_id': 'Frédéric Parrenin',
#   'target_id': 'Amaëlle Landais',
#   'strength': 14},
#  {'source_id': 'Yannick Donnadieu',
#   'target_id': 'Yves Goddéris',
#   'strength': 14},
#  {'source_id': 'Jean-François Le Galliard',
#   'target_id': 'Andréaz Dupoué',
#   'strength': 14},
#  {'source_id': 'Franck Lefèvre',
#   'target_id': 'Jean-Yves Chaufray',
#   'strength': 14},
#  {'source_id': 'José Zambonino Infante',
#   'target_id': 'David Mazurais',
#   'strength': 14},
#  {'source_id': 'Bruno Castelle', 'target_id': 'Deborah Idier', 'strength': 14},
#  {'source_id': 'Jean-Philippe Vidal',
#   'target_id': 'Alexandre Devers',
#   'strength': 14},
#  {'source_id': 'Julien Le Sommer',
#   'target_id': 'Thierry Penduff',
#   'strength': 14},
#  {'source_id': 'Alain Hauchecorne',
#   'target_id': 'Sophie Godin-Beekmann',
#   'strength': 14},
#  {'source_id': 'Philippe Ciais', 'target_id': 'Glenn Peters', 'strength': 14},
#  {'source_id': 'Philippe Ciais',
#   'target_id': 'Matthieu Guimberteau',
#   'strength': 14},
#  {'source_id': 'Philippe Ciais', 'target_id': 'Rob Jackson', 'strength': 14},
#  {'source_id': 'Christine Provost',
#   'target_id': 'Nathalie Sennéchael',
#   'strength': 14},
#  {'source_id': 'Etienne Berthier', 'target_id': 'Fanny Brun', 'strength': 14},
#  {'source_id': 'Franck Courchamp', 'target_id': 'Boris Leroy', 'strength': 14},
#  {'source_id': 'Olivier Gagliardini',
#   'target_id': 'Fabien Gillet-Chaulet',
#   'strength': 14},
#  {'source_id': 'Agnès Ducharne',
#   'target_id': 'Frédérique Cheruy',
#   'strength': 14},
#  {'source_id': 'Catherine Ottlé',
#   'target_id': 'Philippe Peylin',
#   'strength': 14},
#  {'source_id': 'Jean-François Huneau',
#   'target_id': 'François Mariotti',
#   'strength': 14},
#  {'source_id': 'Nathalie Ollat', 'target_id': 'Eric Duchêne', 'strength': 14},
#  {'source_id': 'Iñaki Garcia de Cortazar Atauri',
#   'target_id': 'Eric Duchêne',
#   'strength': 14},
#  {'source_id': 'Cyrille Flamant',
#   'target_id': 'Peter Knippertz',
#   'strength': 14},
#  {'source_id': 'Glenn Peters',
#   'target_id': 'Peter Landschützer',
#   'strength': 14},
#  {'source_id': 'Pierre Friedlingstein',
#   'target_id': 'Corinne Le Quéré',
#   'strength': 14},
#  {'source_id': 'Mathieu Cazaunau',
#   'target_id': 'Paola Formenti',
#   'strength': 14},
#  {'source_id': 'Wahida Talantikite',
#   'target_id': 'Séverine Deguen',
#   'strength': 14},
#  {'source_id': 'Géraldine Sarthou',
#   'target_id': 'Hélène Planquette',
#   'strength': 14},
#  {'source_id': 'George R. R. Martin',
#   'target_id': 'Gianni Bellocchi',
#   'strength': 13},
#  {'source_id': 'Serge Hercberg',
#   'target_id': 'Caroline Méjean',
#   'strength': 13},
#  {'source_id': 'Christophe Lecuyer',
#   'target_id': 'Romain Amiot',
#   'strength': 13},
#  {'source_id': 'Bruno Corbara', 'target_id': 'Céline Leroy', 'strength': 13},
#  {'source_id': 'Jean-Luc Dupuy', 'target_id': 'Éric Rigolot', 'strength': 13},
#  {'source_id': 'Vincent Dubreuil',
#   'target_id': 'Beatriz Funatsu',
#   'strength': 13},
#  {'source_id': 'Benoît Hingray',
#   'target_id': 'Guillaume Evin',
#   'strength': 13},
#  {'source_id': 'Daniel Brunstein',
#   'target_id': 'Vincent Jomelli',
#   'strength': 13},
#  {'source_id': 'Yves Bergeron', 'target_id': 'Ahmed Adam Ali', 'strength': 13},
#  {'source_id': 'Jérôme Demarty',
#   'target_id': 'Laurent Kergoat',
#   'strength': 13},
#  {'source_id': 'Hervé Quenol', 'target_id': 'Gwenael Morin', 'strength': 13},
#  {'source_id': 'Christophe Guinet',
#   'target_id': 'Jean-Benoît Charrassin',
#   'strength': 13},
#  {'source_id': 'Olivier Cerdan',
#   'target_id': 'Olivier Evrard',
#   'strength': 13},
#  {'source_id': 'Mohamed Naaim', 'target_id': 'Nicolas Eckert', 'strength': 13},
#  {'source_id': 'Marie Lothon', 'target_id': 'Fabienne Lohou', 'strength': 13},
#  {'source_id': 'David Kaniewski',
#   'target_id': 'Nick Marriner',
#   'strength': 13},
#  {'source_id': 'Yvan Bettarel',
#   'target_id': 'Thierry Bouvier',
#   'strength': 13},
#  {'source_id': 'Pascal Terray',
#   'target_id': 'Sébastien Masson',
#   'strength': 13},
#  {'source_id': 'François Forget',
#   'target_id': 'Franck Lefèvre',
#   'strength': 13},
#  {'source_id': 'Myriam Khodri-Chouchou',
#   'target_id': 'Juliette Mignot',
#   'strength': 13},
#  {'source_id': 'Gilles Bergametti',
#   'target_id': 'Jean-Louis Rajot',
#   'strength': 13},
#  {'source_id': 'Meinrat O. Andreae',
#   'target_id': 'Joel Brito',
#   'strength': 13},
#  {'source_id': 'Caroline Fabioux',
#   'target_id': 'Hélène Hegaret',
#   'strength': 13},
#  {'source_id': 'Hendrik Davi',
#   'target_id': 'Sylvie Oddou Muratorio',
#   'strength': 13},
#  {'source_id': 'Vincent Taillandier',
#   'target_id': "Fabrizio D'Ortenzio",
#   'strength': 13},
#  {'source_id': 'Philippe Ciais',
#   'target_id': 'Pierre Friedlingstein',
#   'strength': 13},
#  {'source_id': 'Philippe Ciais',
#   'target_id': 'Ronny Lauerwald',
#   'strength': 13},
#  {'source_id': 'Philippe Ciais', 'target_id': 'Rob Jackson', 'strength': 13},
#  {'source_id': 'Philippe Ciais',
#   'target_id': 'Peter Landschützer',
#   'strength': 13},
#  {'source_id': 'Patrick Augustin',
#   'target_id': 'Marc Fourmentin',
#   'strength': 13},
#  {'source_id': 'Franck Courchamp',
#   'target_id': 'Céline Bellard',
#   'strength': 13},
#  {'source_id': 'Sébastien Joannin',
#   'target_id': 'Guillemette Menot',
#   'strength': 13},
#  {'source_id': 'Pascale Braconnot',
#   'target_id': 'Masa Kageyama',
#   'strength': 13},
#  {'source_id': 'Christian Kerbiriou',
#   'target_id': 'Isabelle Le Viol',
#   'strength': 13},
#  {'source_id': 'Daniel Berveiller',
#   'target_id': 'Nicolas Delpierre',
#   'strength': 13},
#  {'source_id': 'Salah Er-Raki', 'target_id': 'Lionel Jarlan', 'strength': 13},
#  {'source_id': 'Cyrille Flamant',
#   'target_id': 'Julien Totems',
#   'strength': 13},
#  {'source_id': 'Ronan Fablet', 'target_id': 'Pierre Tandeo', 'strength': 13},
#  {'source_id': 'Glenn Peters', 'target_id': 'Wouter Peters', 'strength': 13},
#  {'source_id': 'Samuel Morin', 'target_id': 'Marie Dumont', 'strength': 13},
#  {'source_id': 'Denis Ruelland', 'target_id': 'Yves Tramblay', 'strength': 13},
#  {'source_id': 'Clément Stahl', 'target_id': 'Sabrina Coste', 'strength': 13},
#  {'source_id': 'Corinne Le Quéré',
#   'target_id': 'Wouter Peters',
#   'strength': 13},
#  {'source_id': 'Frédéric Chevallier',
#   'target_id': 'Peter Landschützer',
#   'strength': 13},
#  {'source_id': 'Frédéric Thévenet',
#   'target_id': 'Emmanouil Romanias',
#   'strength': 13},
#  {'source_id': 'Virginie Baldy',
#   'target_id': 'Mathieu Santonja',
#   'strength': 13},
#  {'source_id': 'Bernard Cappelaere',
#   'target_id': 'Laurent Kergoat',
#   'strength': 13},
#  {'source_id': 'Sönke Zaehle', 'target_id': 'Daniel S. Goll', 'strength': 13},
#  {'source_id': 'Paola Formenti',
#   'target_id': 'Claudia Di Biagio',
#   'strength': 13},
#  {'source_id': 'Laurent Arnaud', 'target_id': 'Marie Dumont', 'strength': 12},
#  {'source_id': 'Serge Hercberg',
#   'target_id': 'Mathilde Touvier',
#   'strength': 12},
#  {'source_id': 'Hervé Claustre',
#   'target_id': "Fabrizio D'Ortenzio",
#   'strength': 12},
#  {'source_id': 'Nathalie Combourieu-Nebout',
#   'target_id': 'Odile Peyron',
#   'strength': 12},
#  {'source_id': 'Marc Verlaque',
#   'target_id': 'Aurélie Blanfuné',
#   'strength': 12},
#  {'source_id': 'Bertrand Chapron',
#   'target_id': 'Nicolas Reul',
#   'strength': 12},
#  {'source_id': 'Rachid Cheddadi',
#   'target_id': 'Matthieu Carré',
#   'strength': 12},
#  {'source_id': 'Bruno Hérault', 'target_id': 'Damien Bonal', 'strength': 12},
#  {'source_id': 'Sandrine Anquetin',
#   'target_id': 'Arona Diedhiou',
#   'strength': 12},
#  {'source_id': 'Laurent Bopp',
#   'target_id': 'Ralph F. Keeling',
#   'strength': 12},
#  {'source_id': 'Laurent Bopp',
#   'target_id': 'Peter Landschützer',
#   'strength': 12},
#  {'source_id': 'Nicolas Massei',
#   'target_id': 'Matthieu Fournier',
#   'strength': 12},
#  {'source_id': 'Pierre-Olivier Antoine',
#   'target_id': 'Laurent Marivaux',
#   'strength': 12},
#  {'source_id': 'Vincent Favier', 'target_id': 'Cécile Agosta', 'strength': 12},
#  {'source_id': 'Fabien Durand', 'target_id': 'Fabrice Papa', 'strength': 12},
#  {'source_id': 'Olivier Boucher',
#   'target_id': 'Yves Balkanski',
#   'strength': 12},
#  {'source_id': 'Bernadette Tessier',
#   'target_id': 'Pierre Weill',
#   'strength': 12},
#  {'source_id': 'Pierre Sepulchre',
#   'target_id': 'Yannick Donnadieu',
#   'strength': 12},
#  {'source_id': 'Régis Dupuy',
#   'target_id': 'Alfons Schwarzenböeck',
#   'strength': 12},
#  {'source_id': 'Olivier Gimenez', 'target_id': 'Roger Pradel', 'strength': 12},
#  {'source_id': 'Wilfried Thuiller',
#   'target_id': 'Niklaus E. Zimmermann',
#   'strength': 12},
#  {'source_id': 'Matthieu Lengaigne',
#   'target_id': 'Gurvan Madec',
#   'strength': 12},
#  {'source_id': 'Michel Duru', 'target_id': 'Olivier Thérond', 'strength': 12},
#  {'source_id': 'Bernard Aumont',
#   'target_id': 'Marie Camredon',
#   'strength': 12},
#  {'source_id': 'Caroline Fabioux',
#   'target_id': 'Philippe Soudant',
#   'strength': 12},
#  {'source_id': 'Stéphanie Jenouvrier',
#   'target_id': 'Christophe Barbraud',
#   'strength': 12},
#  {'source_id': 'Bernard Legras',
#   'target_id': 'Pasquale Sellitto',
#   'strength': 12},
#  {'source_id': 'Juliette Mignot',
#   'target_id': 'Guillaume Gastineau',
#   'strength': 12},
#  {'source_id': 'Philippe Ciais',
#   'target_id': 'Frédéric Frappart',
#   'strength': 12},
#  {'source_id': 'Philippe Ciais',
#   'target_id': 'Ralph F. Keeling',
#   'strength': 12},
#  {'source_id': 'Éric Rigolot', 'target_id': 'François Pimont', 'strength': 12},
#  {'source_id': 'Marie-Josèphe Amiot-Carlin',
#   'target_id': 'Nicole Darmon',
#   'strength': 12},
#  {'source_id': 'Marie-Josèphe Amiot-Carlin',
#   'target_id': 'Marlène Perignon',
#   'strength': 12},
#  {'source_id': 'Alain Miffre', 'target_id': 'Patrick Rairoux', 'strength': 12},
#  {'source_id': 'Céline Leroy',
#   'target_id': 'Jean-François Carrias',
#   'strength': 12},
#  {'source_id': 'François Julien Munoz',
#   'target_id': 'Cyrille Violle',
#   'strength': 12},
#  {'source_id': 'Olivier Gagliardini',
#   'target_id': 'Fabien Gillet-Chaulet',
#   'strength': 12},
#  {'source_id': 'Ralph F. Keeling',
#   'target_id': 'Corinne Le Quéré',
#   'strength': 12},
#  {'source_id': 'Bruno Petton', 'target_id': 'Fabrice Pernet', 'strength': 12},
#  {'source_id': 'Guillaume Mitta',
#   'target_id': 'Jérémie Vidal-Dupiol',
#   'strength': 12},
#  {'source_id': 'Pascale Braconnot',
#   'target_id': 'Olivier Marti',
#   'strength': 12},
#  {'source_id': 'Nicolas Gruber',
#   'target_id': 'Corinne Le Quéré',
#   'strength': 12},
#  {'source_id': 'Jean-François Huneau',
#   'target_id': 'Hélène Fouillet',
#   'strength': 12},
#  {'source_id': 'Olivier Favez',
#   'target_id': 'Jean-Eudes Petit',
#   'strength': 12},
#  {'source_id': 'Eric Guilyardi',
#   'target_id': 'Jérôme Vialard',
#   'strength': 12},
#  {'source_id': 'Nicolas Jourdain',
#   'target_id': 'Cécile Agosta',
#   'strength': 12},
#  {'source_id': 'Nathalie Ollat',
#   'target_id': 'Iñaki Garcia de Cortazar Atauri',
#   'strength': 12},
#  {'source_id': 'Nathalie Ollat',
#   'target_id': 'Philippe Vivin',
#   'strength': 12},
#  {'source_id': 'Nathalie Niquil',
#   'target_id': 'Géraldine Lassalle',
#   'strength': 12},
#  {'source_id': 'Caroline Méjean',
#   'target_id': 'Emmanuelle Kesse-Guyot',
#   'strength': 12},
#  {'source_id': 'Caroline Méjean',
#   'target_id': 'Sandrine Peneau',
#   'strength': 12},
#  {'source_id': 'Pierre Friedlingstein',
#   'target_id': 'Sönke Zaehle',
#   'strength': 12},
#  {'source_id': 'Mohamed Maanan', 'target_id': 'Pierre Pouzet', 'strength': 12},
#  {'source_id': 'Olivier Aumont',
#   'target_id': 'Roland Séférian',
#   'strength': 12},
#  {'source_id': 'Frédéric Chevallier',
#   'target_id': 'Yilong Wang',
#   'strength': 12},
#  {'source_id': 'Sakina-Dorothée Ayata',
#   'target_id': 'Jean-Olivier Irisson',
#   'strength': 12},
#  {'source_id': 'Mathieu Morlighem',
#   'target_id': 'Angelika Humbert',
#   'strength': 12},
#  {'source_id': 'Hélène Seroussi',
#   'target_id': 'Angelika Humbert',
#   'strength': 12},
#  {'source_id': 'Tarik Meziane',
#   'target_id': 'Frédéric Olivier',
#   'strength': 12},
#  {'source_id': 'Odran Sourdeval',
#   'target_id': 'Johannes Quaas',
#   'strength': 12},
#  {'source_id': 'Gaël Lecellier',
#   'target_id': 'Véronique Berteaux-Lecellier',
#   'strength': 12},
#  {'source_id': 'Emmanuelle Kesse-Guyot',
#   'target_id': 'Sandrine Peneau',
#   'strength': 12},
#  {'source_id': 'Davide Faranda',
#   'target_id': 'Gabriele Messori',
#   'strength': 12},
#  {'source_id': 'Martin Vancoppenolle',
#   'target_id': 'François Massonnet',
#   'strength': 12},
#  {'source_id': 'Fatima Laggoun-Défarge',
#   'target_id': 'Sébastien Gogo',
#   'strength': 11},
#  {'source_id': 'Gilles Ramstein',
#   'target_id': 'Camille Contoux',
#   'strength': 11},
#  {'source_id': 'Didier Bourlès',
#   'target_id': 'Irene Schimmelpfennig',
#   'strength': 11},
#  {'source_id': 'Claude Estournel',
#   'target_id': 'Pierre Testor',
#   'strength': 11},
#  {'source_id': 'Thierry Gauquelin',
#   'target_id': 'Catherine Fernandez',
#   'strength': 11},
#  {'source_id': 'Marc Pagano',
#   'target_id': 'François Carlotti',
#   'strength': 11},
#  {'source_id': 'Benoît Laignel',
#   'target_id': 'Nicolas Massei',
#   'strength': 11},
#  {'source_id': 'Laurent Bopp',
#   'target_id': 'Lester Kwiatkowski',
#   'strength': 11},
#  {'source_id': 'Laurent Bopp',
#   'target_id': 'Pierre Friedlingstein',
#   'strength': 11},
#  {'source_id': 'Abdelwahid Mellouki',
#   'target_id': 'Véronique Daële',
#   'strength': 11},
#  {'source_id': 'Eric Ceschia', 'target_id': 'Tiphaine Tallec', 'strength': 11},
#  {'source_id': 'Jacques Pelon',
#   'target_id': 'Vincent Mariage',
#   'strength': 11},
#  {'source_id': 'Anne Lorrain', 'target_id': 'David Point', 'strength': 11},
#  {'source_id': 'François Forget',
#   'target_id': 'Jean-Yves Chaufray',
#   'strength': 11},
#  {'source_id': 'Stéphanie Barrillon',
#   'target_id': 'Anne Petrenko',
#   'strength': 11},
#  {'source_id': 'Stéphanie Barrillon',
#   'target_id': 'Andrea Doglioli',
#   'strength': 11},
#  {'source_id': 'Myriam Khodri-Chouchou',
#   'target_id': 'Alan Robock',
#   'strength': 11},
#  {'source_id': 'Bruno Locatelli',
#   'target_id': 'Sandra Lavorel',
#   'strength': 11},
#  {'source_id': 'Bernard Barnier',
#   'target_id': 'Jean-Marc Molines',
#   'strength': 11},
#  {'source_id': 'Frédéric Parrenin',
#   'target_id': 'Valérie Masson-Delmotte',
#   'strength': 11},
#  {'source_id': 'Wilfried Thuiller',
#   'target_id': 'Sébastien Lavergne',
#   'strength': 11},
#  {'source_id': 'Sandra Lavorel',
#   'target_id': 'Emilie Crouzat',
#   'strength': 11},
#  {'source_id': 'Milan Chytrý', 'target_id': 'Jonathan Lenoir', 'strength': 11},
#  {'source_id': 'François Colas',
#   'target_id': 'Vincent Echevin',
#   'strength': 11},
#  {'source_id': "François Le Loc'h",
#   'target_id': 'Nathalie Niquil',
#   'strength': 11},
#  {'source_id': 'Youen Vermard', 'target_id': 'Paul Marchal', 'strength': 11},
#  {'source_id': 'Bruno Charrière',
#   'target_id': 'Richard Sempéré',
#   'strength': 11},
#  {'source_id': 'Hélène Roux',
#   'target_id': 'Pierre-André Garambois',
#   'strength': 11},
#  {'source_id': 'Catherine Fernandez',
#   'target_id': 'Elena Ormeño Lafuente',
#   'strength': 11},
#  {'source_id': 'Bruno Castelle',
#   'target_id': 'Arthur Robinet',
#   'strength': 11},
#  {'source_id': 'Hélène Magalon', 'target_id': 'Pauline Gélin', 'strength': 11},
#  {'source_id': 'Patrick Chazette',
#   'target_id': 'Alexandre Baron',
#   'strength': 11},
#  {'source_id': 'Patrick Chazette',
#   'target_id': 'Julien Totems',
#   'strength': 11},
#  {'source_id': 'Thierry Thibaut',
#   'target_id': 'Sandrine Ruitton',
#   'strength': 11},
#  {'source_id': 'Amaëlle Landais',
#   'target_id': 'Mathieu Casado',
#   'strength': 11},
#  {'source_id': 'Frédéric Gazeau', 'target_id': 'Cécile Guieu', 'strength': 11},
#  {'source_id': 'Jean-Pierre Wigneron',
#   'target_id': 'Frédéric Frappart',
#   'strength': 11},
#  {'source_id': 'Jean-Pierre Wigneron',
#   'target_id': 'Amen Mohammed Al-Yaari',
#   'strength': 11},
#  {'source_id': 'Jean-François Doussin',
#   'target_id': 'Paola Formenti',
#   'strength': 11},
#  {'source_id': 'Sophie Christine Drogue',
#   'target_id': 'Marlène Perignon',
#   'strength': 11},
#  {'source_id': 'Philippe Ciais', 'target_id': 'Wei Li', 'strength': 11},
#  {'source_id': 'Philippe Ciais',
#   'target_id': 'Ronny Lauerwald',
#   'strength': 11},
#  {'source_id': 'Philippe Ciais',
#   'target_id': 'Daniel S. Goll',
#   'strength': 11},
#  {'source_id': 'Christine Provost',
#   'target_id': 'Camila Artana',
#   'strength': 11},
#  {'source_id': 'Serge Suanez', 'target_id': 'Pierre Stéphan', 'strength': 11},
#  {'source_id': 'Serge Suanez', 'target_id': "France Floc'h", 'strength': 11},
#  {'source_id': 'Didier Roche',
#   'target_id': 'Nathaëlle Bouttes',
#   'strength': 11},
#  {'source_id': 'Emmanuel Witrant',
#   'target_id': 'Patricia Martinerie',
#   'strength': 11},
#  {'source_id': 'Céline Leroy', 'target_id': 'Régis Céréghino', 'strength': 11},
#  {'source_id': 'Céline Leroy',
#   'target_id': 'Olivier Dézerald',
#   'strength': 11},
#  {'source_id': 'Xavier Bertin', 'target_id': 'Kévin Martins', 'strength': 11},
#  {'source_id': 'Alexis Joly', 'target_id': 'Hervé Goëau', 'strength': 11},
#  {'source_id': 'Claire Lo Monaco',
#   'target_id': 'Nicolas Metzl',
#   'strength': 11},
#  {'source_id': 'Nicolas Vuichard',
#   'target_id': 'Philippe Peylin',
#   'strength': 11},
#  {'source_id': 'Marie Gosme', 'target_id': 'Christian Dupraz', 'strength': 11},
#  {'source_id': 'Ralph F. Keeling',
#   'target_id': 'Glenn Peters',
#   'strength': 11},
#  {'source_id': 'Didier Swingedouw',
#   'target_id': 'Eric Guilyardi',
#   'strength': 11},
#  {'source_id': 'Nadia Maïzi', 'target_id': 'Edi Assoumou', 'strength': 11},
#  {'source_id': 'Nicolas Gruber',
#   'target_id': 'Frédéric Chevallier',
#   'strength': 11},
#  {'source_id': 'Pierre Bonnet', 'target_id': 'Hervé Goëau', 'strength': 11},
#  {'source_id': 'Virginie Marecal',
#   'target_id': 'Jonathan Guth',
#   'strength': 11},
#  {'source_id': 'David Amouroux',
#   'target_id': 'Sylvain Bérail',
#   'strength': 11},
#  {'source_id': 'Glenn Peters', 'target_id': 'Dorothee Bakker', 'strength': 11},
#  {'source_id': 'Jérémie Mouginot',
#   'target_id': 'Mathieu Morlighem',
#   'strength': 11},
#  {'source_id': 'Samuel Morin', 'target_id': 'Marie Dumont', 'strength': 11},
#  {'source_id': 'Thierry Améglio',
#   'target_id': 'Guillaume Charrier',
#   'strength': 11},
#  {'source_id': 'Cathy Clerbaux', 'target_id': 'Maya George', 'strength': 11},
#  {'source_id': 'Yann Leroy', 'target_id': 'François Cluzel', 'strength': 11},
#  {'source_id': 'Corinne Le Quéré',
#   'target_id': 'Dorothee Bakker',
#   'strength': 11},
#  {'source_id': 'Marion Gehlen',
#   'target_id': 'Roland Séférian',
#   'strength': 11},
#  {'source_id': 'Cécile Agosta',
#   'target_id': 'Xavier Fettweis',
#   'strength': 11},
#  {'source_id': 'Cécile Agosta', 'target_id': 'Charles Amory', 'strength': 11},
#  {'source_id': 'Cécile Agosta',
#   'target_id': 'Xavier Fettweis',
#   'strength': 11},
#  {'source_id': 'Gilles Bareille',
#   'target_id': 'Christophe Pecheyran',
#   'strength': 11},
#  {'source_id': 'Filipe Aires', 'target_id': 'Victor Pellet', 'strength': 11},
#  {'source_id': 'Benjamin Alles',
#   'target_id': 'Sandrine Peneau',
#   'strength': 11},
#  {'source_id': 'Sönke Zaehle', 'target_id': 'Ana Bastos', 'strength': 11},
#  {'source_id': 'Sönke Zaehle', 'target_id': 'Fortunat Joos', 'strength': 11},
#  {'source_id': 'Odile Peyron', 'target_id': 'Boris Vannière', 'strength': 11},
#  {'source_id': 'Wouter Peters', 'target_id': 'Ana Bastos', 'strength': 11},
#  {'source_id': 'Anni Maattanen',
#   'target_id': 'Millour Ehouarn',
#   'strength': 11},
#  {'source_id': 'Charles-François Boudouresque',
#   'target_id': 'Sandrine Ruitton',
#   'strength': 10},
#  {'source_id': 'Bruno Corbara',
#   'target_id': 'Régis Céréghino',
#   'strength': 10},
#  {'source_id': 'Eric Feunteun', 'target_id': 'Nils Teichert', 'strength': 10},
#  {'source_id': 'Mireille Harmelin-Vivien',
#   'target_id': 'Daniela Bănaru',
#   'strength': 10},
#  {'source_id': 'Hervé Claustre',
#   'target_id': 'Catherine Schmechtig',
#   'strength': 10},
#  {'source_id': 'Slimane Bekki',
#   'target_id': 'Myriam Khodri-Chouchou',
#   'strength': 10},
#  {'source_id': 'Didier Bourlès',
#   'target_id': 'Vincent Favier',
#   'strength': 10},
#  {'source_id': 'Bertrand Chapron',
#   'target_id': 'Fabrice Ardhuin',
#   'strength': 10},
#  {'source_id': 'Guy Claireaux',
#   'target_id': 'José Zambonino Infante',
#   'strength': 10},
#  {'source_id': 'Marc Calvet', 'target_id': 'Magali  Delmas', 'strength': 10},
#  {'source_id': 'Cornelis Van Leeuwen',
#   'target_id': 'Iñaki Garcia de Cortazar Atauri',
#   'strength': 10},
#  {'source_id': 'Daniel Raucoules',
#   'target_id': 'Marcello De Michele',
#   'strength': 10},
#  {'source_id': 'Bruno Hérault', 'target_id': 'Clément Stahl', 'strength': 10},
#  {'source_id': 'Denis Mercier', 'target_id': 'Axel Creach', 'strength': 10},
#  {'source_id': 'Wolfgang Cramer',
#   'target_id': 'Alberte Bondeau',
#   'strength': 10},
#  {'source_id': 'Yves Bergeron',
#   'target_id': 'Christelle Hély-Alleaume',
#   'strength': 10},
#  {'source_id': 'Laurent Bopp', 'target_id': 'Philippe Ciais', 'strength': 10},
#  {'source_id': 'Laurent Bopp', 'target_id': 'Wouter Peters', 'strength': 10},
#  {'source_id': 'Laurent Bopp', 'target_id': 'Dorothee Bakker', 'strength': 10},
#  {'source_id': 'Emmanuelle Vennin',
#   'target_id': 'Arnaud Brayard',
#   'strength': 10},
#  {'source_id': 'Laurent Testut', 'target_id': 'Fabien Durand', 'strength': 10},
#  {'source_id': 'Laurent Coppola',
#   'target_id': 'Laurent Mortier',
#   'strength': 10},
#  {'source_id': 'Étienne Prévost',
#   'target_id': 'Étienne Rivot',
#   'strength': 10},
#  {'source_id': 'Chris Bowler',
#   'target_id': 'Pierre E. Galand',
#   'strength': 10},
#  {'source_id': 'Hervé Quenol', 'target_id': 'Cyril Tissot', 'strength': 10},
#  {'source_id': 'Michel Lang', 'target_id': 'Benjamin Renard', 'strength': 10},
#  {'source_id': 'Karine Sellegri',
#   'target_id': 'Clémence Rose',
#   'strength': 10},
#  {'source_id': 'Dominique Mouazé',
#   'target_id': 'Bernadette Tessier',
#   'strength': 10},
#  {'source_id': 'Dominique Mouazé',
#   'target_id': 'Pierre Weill',
#   'strength': 10},
#  {'source_id': 'Vincent Favier',
#   'target_id': 'Irene Schimmelpfennig',
#   'strength': 10},
#  {'source_id': 'Vincent Favier',
#   'target_id': 'Jonathan Wille',
#   'strength': 10},
#  {'source_id': 'Gwenaël Berthet',
#   'target_id': 'Bernard Legras',
#   'strength': 10},
#  {'source_id': 'Benjamin Sultan',
#   'target_id': 'Dimitri Defrance',
#   'strength': 10},
#  {'source_id': 'Jacques Pelon',
#   'target_id': 'Jean-Christophe Raut',
#   'strength': 10},
#  {'source_id': 'Anne Lorrain', 'target_id': 'Gauthier Schaal', 'strength': 10},
#  {'source_id': 'Anne Lorrain', 'target_id': 'Valérie Allain', 'strength': 10},
#  {'source_id': 'Pierre Testor',
#   'target_id': 'Xavier Durrieu de Madron',
#   'strength': 10},
#  {'source_id': 'Pierre Testor',
#   'target_id': "Fabrizio D'Ortenzio",
#   'strength': 10},
#  {'source_id': 'Pierre Testor', 'target_id': 'Anthony Bosse', 'strength': 10},
#  {'source_id': 'Eric Gaume',
#   'target_id': 'Olivier Renaud Payrastre',
#   'strength': 10},
#  {'source_id': 'Thomas Servais',
#   'target_id': 'Borja Cascales-Miñana',
#   'strength': 10},
#  {'source_id': 'Hélène Rey-Valette',
#   'target_id': 'Bénédicte Rulleau',
#   'strength': 10},
#  {'source_id': 'Jean-Marc Touzard',
#   'target_id': 'Iñaki Garcia de Cortazar Atauri',
#   'strength': 10},
#  {'source_id': 'Jean-Marc Touzard',
#   'target_id': 'Hervé Hannin',
#   'strength': 10},
#  {'source_id': 'Jean-Marc Touzard',
#   'target_id': 'Eric Duchêne',
#   'strength': 10},
#  {'source_id': 'François Lefèvre',
#   'target_id': 'Hendrik Davi',
#   'strength': 10},
#  {'source_id': 'Alexis Chaigneau',
#   'target_id': 'Arnaud Bertrand',
#   'strength': 10},
#  {'source_id': 'Aurélien Dommergue',
#   'target_id': 'Olivier Magand',
#   'strength': 10},
#  {'source_id': 'Vincent Moron',
#   'target_id': 'Pierre Camberlin',
#   'strength': 10},
#  {'source_id': 'Laurent Deguillaume',
#   'target_id': 'Angelica Bianco',
#   'strength': 10},
#  {'source_id': 'Frédéric Huneau',
#   'target_id': 'Sébastien Santoni',
#   'strength': 10},
#  {'source_id': 'Olivier Maury', 'target_id': 'Olivier Aumont', 'strength': 10},
#  {'source_id': 'Yannick Donnadieu',
#   'target_id': 'Frédéric Fluteau',
#   'strength': 10},
#  {'source_id': 'Yannick Donnadieu',
#   'target_id': 'Alexandre Pohl',
#   'strength': 10},
#  {'source_id': 'François-Marie Bréon',
#   'target_id': 'Grégoire Broquet',
#   'strength': 10},
#  {'source_id': 'Nicolas Caillon',
#   'target_id': 'Joël Savarino',
#   'strength': 10},
#  {'source_id': 'Amaëlle Landais',
#   'target_id': 'Patricia Martinerie',
#   'strength': 10},
#  {'source_id': 'Vincent Rey', 'target_id': 'Julien Touboul', 'strength': 10},
#  {'source_id': 'Sophie Christine Drogue',
#   'target_id': 'Marie-Josèphe Amiot-Carlin',
#   'strength': 10},
#  {'source_id': 'Philippe Ciais',
#   'target_id': 'Peter H. Freer-Smith',
#   'strength': 10},
#  {'source_id': 'Philippe Ciais', 'target_id': 'Wouter Peters', 'strength': 10},
#  {'source_id': 'Philippe Ciais', 'target_id': 'Rongming Wang', 'strength': 10},
#  {'source_id': 'Philippe Ciais',
#   'target_id': 'Dorothee Bakker',
#   'strength': 10},
#  {'source_id': 'Gurvan Madec', 'target_id': 'Eric Guilyardi', 'strength': 10},
#  {'source_id': 'Bernard Yannou', 'target_id': 'Yann Leroy', 'strength': 10},
#  {'source_id': 'Bernard Yannou',
#   'target_id': 'François Cluzel',
#   'strength': 10},
#  {'source_id': 'Etienne Berthier',
#   'target_id': 'Simon Gascoin',
#   'strength': 10},
#  {'source_id': 'Françoise Daverat',
#   'target_id': 'Christophe Pecheyran',
#   'strength': 10},
#  {'source_id': 'Isabelle Pison',
#   'target_id': 'Antoine Berchet',
#   'strength': 10},
#  {'source_id': 'Cécile Guieu',
#   'target_id': 'Matthieu Bressac',
#   'strength': 10},
#  {'source_id': 'Charles Perrin',
#   'target_id': 'François Bourgin',
#   'strength': 10},
#  {'source_id': 'Nicolas Vuichard',
#   'target_id': 'Nicolas Viovy',
#   'strength': 10},
#  {'source_id': 'Nicolas Vuichard',
#   'target_id': 'Sönke Zaehle',
#   'strength': 10},
#  {'source_id': 'Mathilde Touvier',
#   'target_id': 'Emmanuelle Kesse-Guyot',
#   'strength': 10},
#  {'source_id': 'Eve Toulza', 'target_id': 'Guillaume Mitta', 'strength': 10},
#  {'source_id': 'Pierre Sabatier',
#   'target_id': 'Jérôme Poulenard',
#   'strength': 10},
#  {'source_id': 'Yves Richard', 'target_id': 'Benjamin Bois', 'strength': 10},
#  {'source_id': 'Julien Cote', 'target_id': 'Elvire Bestion', 'strength': 10},
#  {'source_id': 'Grégoire Broquet', 'target_id': 'Yilong Wang', 'strength': 10},
#  {'source_id': 'Hélène Hegaret',
#   'target_id': 'Christophe Lambert',
#   'strength': 10},
#  {'source_id': 'Hervé Cochard',
#   'target_id': 'José Manuel Torres-Ruiz',
#   'strength': 10},
#  {'source_id': 'Christel Bouet',
#   'target_id': 'Jean-Louis Rajot',
#   'strength': 10},
#  {'source_id': 'Nadine Locoge',
#   'target_id': 'Stéphane Sauvage',
#   'strength': 10},
#  {'source_id': 'Michaël Berhanu', 'target_id': 'Eric Falcon', 'strength': 10},
#  {'source_id': 'Hervé Jactel', 'target_id': 'Kris Verheyen', 'strength': 10},
#  {'source_id': 'Caroline Méjean',
#   'target_id': 'Benjamin Alles',
#   'strength': 10},
#  {'source_id': 'Salah Er-Raki', 'target_id': 'Said Khabba', 'strength': 10},
#  {'source_id': 'Karine Desboeufs',
#   'target_id': 'Paola Formenti',
#   'strength': 10},
#  {'source_id': 'Franck Bourrier',
#   'target_id': 'Nicolas Eckert',
#   'strength': 10},
#  {'source_id': 'Pierre Friedlingstein',
#   'target_id': 'Wouter Peters',
#   'strength': 10},
#  {'source_id': 'Pierre Friedlingstein',
#   'target_id': 'Peter Landschützer',
#   'strength': 10},
#  {'source_id': 'Pierre Friedlingstein',
#   'target_id': 'Rob Jackson',
#   'strength': 10},
#  {'source_id': 'Denis Ruelland',
#   'target_id': 'Alain Dezetter',
#   'strength': 10},
#  {'source_id': 'Cathy Clerbaux',
#   'target_id': 'Pierre-François Coheur',
#   'strength': 10},
#  {'source_id': 'Irene Schimmelpfennig',
#   'target_id': 'Georges Aumaître',
#   'strength': 10},
#  {'source_id': 'Guillaume Thirel',
#   'target_id': 'David Dorchies',
#   'strength': 10},
#  {'source_id': 'Mehrez Zribi',
#   'target_id': 'Nicolas Baghdadi',
#   'strength': 10},
#  {'source_id': 'Clément Albergel',
#   'target_id': 'Jean-Christophe Calvet',
#   'strength': 10},
#  {'source_id': 'Pascal Yiou', 'target_id': 'Julien Cattiaux', 'strength': 10},
#  {'source_id': 'Olivier Aumont', 'target_id': 'Marion Gehlen', 'strength': 10},
#  {'source_id': 'Frédéric Chevallier',
#   'target_id': 'Marion Gehlen',
#   'strength': 10},
#  {'source_id': 'Frédéric Chevallier',
#   'target_id': 'Rob Jackson',
#   'strength': 10},
#  {'source_id': 'Thierry Penduff',
#   'target_id': 'William Llovel',
#   'strength': 10},
#  {'source_id': 'Thierry Penduff',
#   'target_id': 'Quentin Jamet',
#   'strength': 10},
#  {'source_id': 'Valentin Duflot',
#   'target_id': 'Guillaume Payen',
#   'strength': 10},
#  {'source_id': 'Cindy Lebeaupin Brossier',
#   'target_id': 'Philippe Drobinski',
#   'strength': 10},
#  {'source_id': 'Sylvain Caurla',
#   'target_id': 'Philippe Delacote',
#   'strength': 10},
#  {'source_id': 'Lauriane Saunier-Batté',
#   'target_id': 'Constantin Ardilouze',
#   'strength': 10},
#  {'source_id': 'Bruno Turcq',
#   'target_id': 'Patricia Moreira Turcq',
#   'strength': 10},
#  {'source_id': 'Nicolas Eckert',
#   'target_id': 'Robin Mainieri',
#   'strength': 10},
#  {'source_id': 'Michel Ramonet',
#   'target_id': 'Irène Xueref-Remy',
#   'strength': 10},
#  {'source_id': 'Wouter Peters',
#   'target_id': 'Peter Landschützer',
#   'strength': 10},
#  {'source_id': 'Wouter Peters', 'target_id': 'Rob Jackson', 'strength': 10},
#  {'source_id': 'David Mazurais',
#   'target_id': 'Arianna Servili',
#   'strength': 10},
#  {'source_id': 'Fortunat Joos', 'target_id': 'Rob Jackson', 'strength': 10},
# ...
#  {'source_id': 'Matthieu Lengaigne',
#   'target_id': 'Nicolas Jourdain',
#   'strength': 8},
#  {'source_id': 'Michel Duru', 'target_id': 'Guillaume Martin', 'strength': 8},
#  {'source_id': 'Fabien Arnaud',
#   'target_id': 'Charline Giguet-Covex',
#   'strength': 8},
#  {'source_id': 'Fabien Arnaud',
#   'target_id': 'Anne-Lise Develle',
#   'strength': 8},
#  {'source_id': 'Frédéric Guiter',
#   'target_id': 'Elodie Brisset',
#   'strength': 8},
#  {'source_id': 'Hilaire Drouineau',
#   'target_id': 'Jérémy Lobry',
#   'strength': 8},
#  {'source_id': 'Yannick Donnadieu',
#   'target_id': 'Guillaume Dupont-Nivet',
#   'strength': 8},
#  {'source_id': 'Yannick Donnadieu',
#   'target_id': 'Delphine Tardif',
#   'strength': 8},
#  {'source_id': 'Didier Hauglustaine',
#   'target_id': 'Philippe Ciais',
#   'strength': 8},
#  {'source_id': 'Didier Hauglustaine',
#   'target_id': 'Yves Balkanski',
#   'strength': 8},
#  {'source_id': 'Jean-Marc Fromentin',
#   'target_id': 'Pablo Brosset',
#   'strength': 8},
#  {'source_id': 'Yann H. Kerr',
#   'target_id': 'Jean-Pierre Wigneron',
#   'strength': 8},
#  {'source_id': 'Yann H. Kerr',
#   'target_id': 'Nemesio J. Rodríguez',
#   'strength': 8},
#  {'source_id': 'Sylvain Delzon', 'target_id': 'Eric Badel', 'strength': 8},
#  {'source_id': 'Sylvain Delzon',
#   'target_id': 'Guillaume Charrier',
#   'strength': 8},
#  {'source_id': 'Franck Lefèvre', 'target_id': 'Anni Maattanen', 'strength': 8},
#  {'source_id': 'José Zambonino Infante',
#   'target_id': 'Arianna Servili',
#   'strength': 8},
#  {'source_id': 'Jean-Philippe Vidal',
#   'target_id': 'Charles Perrin',
#   'strength': 8},
#  {'source_id': 'Stéphanie Jenouvrier',
#   'target_id': 'Christophe Barbraud',
#   'strength': 8},
#  {'source_id': 'Julien Le Sommer', 'target_id': 'Gurvan Madec', 'strength': 8},
#  {'source_id': 'Alain Hauchecorne',
#   'target_id': 'Mustapha Meftah',
#   'strength': 8},
#  {'source_id': 'Thierry Fouchet',
#   'target_id': 'Jérémy Leconte',
#   'strength': 8},
#  {'source_id': 'Sébastien Masson', 'target_id': 'Gurvan Madec', 'strength': 8},
#  {'source_id': 'Sébastien Masson',
#   'target_id': 'Guillaume Samson',
#   'strength': 8},
#  {'source_id': 'Sophie Bastin', 'target_id': 'Thomas Arsouze', 'strength': 8},
#  {'source_id': 'Amaëlle Landais', 'target_id': 'Elise Folz', 'strength': 8},
#  {'source_id': 'Jean-François Doussin',
#   'target_id': 'Aline Gratien',
#   'strength': 8},
#  {'source_id': 'Jean-François Doussin',
#   'target_id': 'Claudia Di Biagio',
#   'strength': 8},
#  {'source_id': 'Claire Chenu', 'target_id': 'Rémi Cardinael', 'strength': 8},
#  {'source_id': 'Philippe Ciais',
#   'target_id': 'P. Friedlingstein',
#   'strength': 8},
#  {'source_id': 'Philippe Ciais',
#   'target_id': 'Emilie Joetzjer',
#   'strength': 8},
#  {'source_id': 'Philippe Ciais', 'target_id': 'Nicolas Gruber', 'strength': 8},
#  {'source_id': 'Philippe Ciais', 'target_id': 'Wei Li', 'strength': 8},
#  {'source_id': 'Philippe Ciais', 'target_id': 'Jinfeng Chang', 'strength': 8},
#  {'source_id': 'Philippe Ciais', 'target_id': 'Sönke Zaehle', 'strength': 8},
#  {'source_id': 'Serge Suanez', 'target_id': 'Ronan Autret', 'strength': 8},
#  {'source_id': 'Bernard Yannou',
#   'target_id': 'Michael Saidani',
#   'strength': 8},
#  {'source_id': 'Didier Roche',
#   'target_id': 'Claire Waelbroeck',
#   'strength': 8},
#  {'source_id': 'Philip Deline', 'target_id': 'Florence Magnin', 'strength': 8},
#  {'source_id': 'Etienne Berthier', 'target_id': 'Fanny Brun', 'strength': 8},
#  {'source_id': 'Emmanuel Mignot', 'target_id': 'André Paquier', 'strength': 8},
#  {'source_id': 'Bertrand Decharme',
#   'target_id': 'Hervé Douville',
#   'strength': 8},
#  {'source_id': 'Paco Bustamante',
#   'target_id': 'Christine Dupuy',
#   'strength': 8},
#  {'source_id': 'Sophie Bonnet', 'target_id': 'Thierry Moutin', 'strength': 8},
#  {'source_id': 'Charles Perrin', 'target_id': 'Éric Sauquet', 'strength': 8},
#  {'source_id': 'Marie-Pierre Ellies-Oury',
#   'target_id': 'Sghaïer Chriki',
#   'strength': 8},
#  {'source_id': 'Sophie Martin', 'target_id': 'Erwann Legrand', 'strength': 8},
#  {'source_id': 'Alexis Joly',
#   'target_id': 'Maximilien Servajean',
#   'strength': 8},
#  {'source_id': 'Fabien Lombard', 'target_id': 'Emilie Boissin', 'strength': 8},
#  {'source_id': 'Fabien Lombard', 'target_id': 'Éric Gilson', 'strength': 8},
#  {'source_id': 'Fabien Lombard', 'target_id': 'Didier Zoccola', 'strength': 8},
#  {'source_id': 'Fabien Lombard',
#   'target_id': 'Didier Forcioli',
#   'strength': 8},
#  {'source_id': 'Fabien Lombard', 'target_id': 'Eric Douville', 'strength': 8},
#  {'source_id': 'Fabien Lombard', 'target_id': 'Emmanuel Boss', 'strength': 8},
#  {'source_id': 'Fabien Lombard',
#   'target_id': 'Sylvain Agostini',
#   'strength': 8},
#  {'source_id': 'Fabien Lombard',
#   'target_id': 'Stéphanie Reynaud',
#   'strength': 8},
#  {'source_id': 'Nicolas Vuichard',
#   'target_id': 'Fabienne Maignan',
#   'strength': 8},
#  {'source_id': 'Mathilde Touvier',
#   'target_id': 'Benjamin Alles',
#   'strength': 8},
#  {'source_id': 'Mathilde Touvier', 'target_id': 'Julia Baudry', 'strength': 8},
#  {'source_id': 'Arnaud Brayard',
#   'target_id': 'Gilles Escarguel',
#   'strength': 8},
#  {'source_id': 'Arnaud Brayard', 'target_id': 'Emmanuel Fara', 'strength': 8},
#  {'source_id': 'Carole Kerdelhué',
#   'target_id': 'Jean-Pierre Rossi',
#   'strength': 8},
#  {'source_id': 'Michel Benoit',
#   'target_id': 'Marissa L. Yates',
#   'strength': 8},
#  {'source_id': 'Christophe Lavaysse',
#   'target_id': 'Cyrille Flamant',
#   'strength': 8},
#  {'source_id': 'Frédéric Angelier',
#   'target_id': 'François Brischoux',
#   'strength': 8},
#  {'source_id': 'Valérie Masson-Delmotte',
#   'target_id': 'Camille Risi',
#   'strength': 8},
#  {'source_id': 'Valérie Masson-Delmotte',
#   'target_id': 'Valérie Daux',
#   'strength': 8},
#  {'source_id': 'Dov Corenblit',
#   'target_id': 'Johannes Steiger',
#   'strength': 8},
#  {'source_id': 'Mickaël Hedde', 'target_id': 'Jérôme Cortet', 'strength': 8},
#  {'source_id': 'Ralph F. Keeling',
#   'target_id': 'Frédéric Chevallier',
#   'strength': 8},
#  {'source_id': 'Ralph F. Keeling',
#   'target_id': 'Peter Landschützer',
#   'strength': 8},
#  {'source_id': 'Guerric Le Maire',
#   'target_id': 'Jean-Paul Laclau',
#   'strength': 8},
#  {'source_id': 'Catherine Ottlé',
#   'target_id': 'Fabienne Maignan',
#   'strength': 8},
#  {'source_id': 'Jean-Yves Chaufray',
#   'target_id': 'Aymeric Spiga',
#   'strength': 8},
#  {'source_id': 'Régis Céréghino',
#   'target_id': 'Jean-François Carrias',
#   'strength': 8},
#  {'source_id': 'Nicolas Jourdain',
#   'target_id': 'Cécile Agosta',
#   'strength': 8},
#  {'source_id': 'Nicolas Jourdain',
#   'target_id': 'Hélène Seroussi',
#   'strength': 8},
#  {'source_id': 'Benjamin Bois', 'target_id': 'Thierry Castel', 'strength': 8},
#  {'source_id': 'Christel Bouet',
#   'target_id': 'Béatrice Marticorena',
#   'strength': 8},
#  {'source_id': 'Melilotus Thyssen',
#   'target_id': 'Gérald Grégori',
#   'strength': 8},
#  {'source_id': 'Marie-Angélina Magne',
#   'target_id': 'Guillaume Martin',
#   'strength': 8},
#  {'source_id': 'Hervé Jactel', 'target_id': 'Luc Barbaro', 'strength': 8},
#  {'source_id': 'Gilles Mailhot',
#   'target_id': 'Marcello Brigante',
#   'strength': 8},
#  {'source_id': 'Emilie Boissin', 'target_id': 'Éric Gilson', 'strength': 8},
#  {'source_id': 'Emilie Boissin',
#   'target_id': 'Didier Forcioli',
#   'strength': 8},
#  {'source_id': 'Emilie Boissin',
#   'target_id': 'Sylvain Agostini',
#   'strength': 8},
#  {'source_id': 'Emilie Boissin',
#   'target_id': 'Stéphanie Reynaud',
#   'strength': 8},
#  {'source_id': 'Éric Gilson', 'target_id': 'Didier Forcioli', 'strength': 8},
#  {'source_id': 'Éric Gilson', 'target_id': 'Eric Douville', 'strength': 8},
#  {'source_id': 'Éric Gilson', 'target_id': 'Pierre E. Galand', 'strength': 8},
#  {'source_id': 'Éric Gilson', 'target_id': 'Emmanuel Boss', 'strength': 8},
#  {'source_id': 'Éric Gilson', 'target_id': 'Sylvain Agostini', 'strength': 8},
#  {'source_id': 'Éric Gilson', 'target_id': 'Stéphanie Reynaud', 'strength': 8},
#  {'source_id': 'Gilles Boulet', 'target_id': 'Lionel Jarlan', 'strength': 8},
#  {'source_id': 'Cyrille Flamant', 'target_id': 'Joel Brito', 'strength': 8},
#  {'source_id': 'Anne Petrenko', 'target_id': 'Gérald Grégori', 'strength': 8},
#  {'source_id': 'Anne Petrenko', 'target_id': 'Roxane Tzortzis', 'strength': 8},
#  {'source_id': 'David Amouroux', 'target_id': 'Zoyne Pedrero', 'strength': 8},
#  {'source_id': 'Olivier Magand', 'target_id': 'Hélène Angot', 'strength': 8},
#  {'source_id': 'Glenn Peters',
#   'target_id': 'Peter H. Freer-Smith',
#   'strength': 8},
#  {'source_id': 'Glenn Peters', 'target_id': 'Sönke Zaehle', 'strength': 8},
#  {'source_id': 'Glenn Peters', 'target_id': 'Ronny Lauerwald', 'strength': 8},
#  {'source_id': 'Jean-Daniel Paris',
#   'target_id': 'Antoine Berchet',
#   'strength': 8},
#  {'source_id': 'Samuel Morin',
#   'target_id': 'Deborah Verfaillie',
#   'strength': 8},
#  {'source_id': 'P. Friedlingstein',
#   'target_id': 'Sönke Zaehle',
#   'strength': 8},
#  {'source_id': 'Pierre Friedlingstein',
#   'target_id': 'Sönke Zaehle',
#   'strength': 8},
#  {'source_id': 'Hélène Tabouret',
#   'target_id': 'Gilles Bareille',
#   'strength': 8},
#  {'source_id': 'Jean Sciare', 'target_id': 'Jean-Eudes Petit', 'strength': 8},
#  {'source_id': 'Cathy Clerbaux', 'target_id': 'Marie Bouillon', 'strength': 8},
#  {'source_id': 'Didier Voisin', 'target_id': 'Marie Dumont', 'strength': 8},
#  {'source_id': 'Jacqueline Boutin',
#   'target_id': 'Audrey Hasson',
#   'strength': 8},
#  {'source_id': 'Irene Schimmelpfennig',
#   'target_id': 'Vincent Jomelli',
#   'strength': 8},
#  {'source_id': 'Jean-Christophe Raut',
#   'target_id': 'Louis Marelle',
#   'strength': 8},
#  {'source_id': 'Fabien Roquet',
#   'target_id': 'Jean-Benoît Charrassin',
#   'strength': 8},
#  {'source_id': 'Abdelfettah Sifeddine',
#   'target_id': 'Bruno Turcq',
#   'strength': 8},
#  {'source_id': 'Ludovic Ravanel',
#   'target_id': 'Emmanuel Salim',
#   'strength': 8},
#  {'source_id': 'Philippe Naveau', 'target_id': 'Pascal Yiou', 'strength': 8},
#  {'source_id': 'Vianney Pichereau',
#   'target_id': 'Sébastien Artigaud',
#   'strength': 8},
#  {'source_id': 'Gérald Grégori',
#   'target_id': 'Roxane Tzortzis',
#   'strength': 8},
#  {'source_id': 'Clément Albergel', 'target_id': 'Simon Munier', 'strength': 8},
#  {'source_id': 'Sylvain Mailler',
#   'target_id': 'Bertrand Bessagnet',
#   'strength': 8},
#  {'source_id': 'Sylvain Mailler', 'target_id': 'Laurent Menut', 'strength': 8},
#  {'source_id': 'Fabienne Maignan',
#   'target_id': 'Frédéric Chevallier',
#   'strength': 8},
#  {'source_id': 'Pascal Yiou', 'target_id': 'Gabriele Messori', 'strength': 8},
#  {'source_id': 'Didier Zoccola',
#   'target_id': 'Didier Forcioli',
#   'strength': 8},
#  {'source_id': 'Didier Zoccola',
#   'target_id': 'Sylvain Agostini',
#   'strength': 8},
#  {'source_id': 'Didier Zoccola',
#   'target_id': 'Stéphanie Reynaud',
#   'strength': 8},
#  {'source_id': 'Frédéric Chevallier',
#   'target_id': 'Wouter Peters',
#   'strength': 8},
#  {'source_id': 'Frédéric Chevallier',
#   'target_id': 'Ana Bastos',
#   'strength': 8},
#  {'source_id': 'Frédéric Chevallier',
#   'target_id': 'Thi Tuyet Trang Chau',
#   'strength': 8},
#  {'source_id': 'Frédéric Chevallier',
#   'target_id': 'Ronny Lauerwald',
#   'strength': 8},
#  {'source_id': 'Frédéric Chevallier',
#   'target_id': 'Dorothee Bakker',
#   'strength': 8},
#  {'source_id': 'David Makowski', 'target_id': 'Tamara Ben-Ari', 'strength': 8},
#  {'source_id': 'Louis-Gaëtan Giraudet',
#   'target_id': 'Philippe Quirion',
#   'strength': 8},
#  {'source_id': 'Lars Stemmann',
#   'target_id': 'Jean-Olivier Irisson',
#   'strength': 8},
#  {'source_id': 'Didier Forcioli', 'target_id': 'Eric Douville', 'strength': 8},
#  {'source_id': 'Didier Forcioli',
#   'target_id': 'Pierre E. Galand',
#   'strength': 8},
#  {'source_id': 'Didier Forcioli', 'target_id': 'Emmanuel Boss', 'strength': 8},
#  {'source_id': 'Didier Forcioli',
#   'target_id': 'Sylvain Agostini',
#   'strength': 8},
#  {'source_id': 'Didier Forcioli',
#   'target_id': 'Stéphanie Reynaud',
#   'strength': 8},
#  {'source_id': 'William Llovel',
#   'target_id': 'Benoit Meyssignac',
#   'strength': 8},
#  {'source_id': 'Mathieu Morlighem',
#   'target_id': 'Aurélien Quiquet',
#   'strength': 8},
#  {'source_id': 'Hélène Seroussi',
#   'target_id': 'Aurélien Quiquet',
#   'strength': 8},
#  {'source_id': 'Hélène Seroussi', 'target_id': 'Cécile Agosta', 'strength': 8},
#  {'source_id': 'Nicolas Viovy', 'target_id': 'Jinfeng Chang', 'strength': 8},
#  {'source_id': 'Marion Gehlen',
#   'target_id': 'Peter Landschützer',
#   'strength': 8},
#  {'source_id': 'Katell Guizien',
#   'target_id': 'Lorenzo Bramanti',
#   'strength': 8},
#  {'source_id': 'Claire Saraux', 'target_id': 'Pablo Brosset', 'strength': 8},
#  {'source_id': 'Patrick Stella',
#   'target_id': 'Benjamin Loubet',
#   'strength': 8},
#  {'source_id': 'Aurélien Quiquet',
#   'target_id': 'Angelika Humbert',
#   'strength': 8},
#  {'source_id': 'Vincent Jomelli',
#   'target_id': 'Joanna Charton',
#   'strength': 8},
#  {'source_id': 'François Cluzel',
#   'target_id': 'Michael Saidani',
#   'strength': 8},
#  {'source_id': 'Anne Johannet',
#   'target_id': 'Guillaume Artigue',
#   'strength': 8},
#  {'source_id': 'Boris Leroy', 'target_id': 'Céline Bellard', 'strength': 8},
#  {'source_id': 'Eric Douville',
#   'target_id': 'Sylvain Agostini',
#   'strength': 8},
#  {'source_id': 'Eric Douville',
#   'target_id': 'Stéphanie Reynaud',
#   'strength': 8},
#  {'source_id': 'Sandrine Ruitton',
#   'target_id': 'Aurélie Blanfuné',
#   'strength': 8},
#  {'source_id': 'Philippe Drobinski',
#   'target_id': 'Thomas Arsouze',
#   'strength': 8},
#  {'source_id': 'Pierre E. Galand',
#   'target_id': 'Sylvain Agostini',
#   'strength': 8},
#  {'source_id': 'Pierre E. Galand',
#   'target_id': 'Stéphanie Reynaud',
#   'strength': 8},
#  {'source_id': 'Céline Bellard',
#   'target_id': 'Camille Leclerc',
#   'strength': 8},
#  {'source_id': 'Matthieu Riva', 'target_id': 'Liine Heikkinen', 'strength': 8},
#  {'source_id': 'Aaron Boone',
#   'target_id': 'Christophe Peugeot',
#   'strength': 8},
#  {'source_id': 'Gianni Bellocchi', 'target_id': 'Romain Lardy', 'strength': 8},
#  {'source_id': 'Peter Knippertz', 'target_id': 'Joel Brito', 'strength': 8},
#  {'source_id': 'Camille Contoux',
#   'target_id': 'Daniel J. Lunt',
#   'strength': 8},
#  {'source_id': 'Benjamin Pohl', 'target_id': 'Thierry Castel', 'strength': 8},
#  {'source_id': "Francesco D'Ovidio",
#   'target_id': 'Andrea Doglioli',
#   'strength': 8},
#  {'source_id': 'Elena Angulo Aguado',
#   'target_id': 'Christophe Diagne',
#   'strength': 8},
#  {'source_id': 'Sarah Safieddine',
#   'target_id': 'Martin Van Damme',
#   'strength': 8},
#  {'source_id': 'Gaël Le Roux',
#   'target_id': 'François De Vleeschouwer',
#   'strength': 8},
#  {'source_id': 'Emmanuel Boss',
#   'target_id': 'Sylvain Agostini',
#   'strength': 8},
#  {'source_id': 'Emmanuel Boss',
#   'target_id': 'Stéphanie Reynaud',
#   'strength': 8},
#  {'source_id': 'Florence Magnin',
#   'target_id': 'Suvrat Kaushik',
#   'strength': 8},
#  {'source_id': 'Lionel Jarlan', 'target_id': 'Yves Tramblay', 'strength': 8},
#  {'source_id': 'Marissa L. Yates',
#   'target_id': 'Gonéri Le Cozannet',
#   'strength': 8},
#  {'source_id': 'Christophe Peugeot',
#   'target_id': 'Laurent Kergoat',
#   'strength': 8},
#  {'source_id': 'Edouard Metzger', 'target_id': 'E. Geslin', 'strength': 8},
#  {'source_id': 'Andrea Doglioli',
#   'target_id': 'Roxane Tzortzis',
#   'strength': 8},
#  {'source_id': 'Davide Faranda',
#   'target_id': 'Gabriele Messori',
#   'strength': 8},
#  {'source_id': 'Emilie Garel',
#   'target_id': 'Sébastien Santoni',
#   'strength': 8},
#  {'source_id': 'Sylvain Agostini',
#   'target_id': 'Stéphanie Reynaud',
#   'strength': 8},
#  {'source_id': 'Eric A. Davidson', 'target_id': 'Rob Jackson', 'strength': 8},
#  {'source_id': 'Dorothee Bakker',
#   'target_id': 'Peter Landschützer',
#   'strength': 8},
#  {'source_id': 'Dorothee Bakker', 'target_id': 'Rob Jackson', 'strength': 8},
#  {'source_id': 'Peter Landschützer',
#   'target_id': 'Rob Jackson',
#   'strength': 8},
#  {'source_id': 'Laurent Arnaud', 'target_id': 'Marie Dumont', 'strength': 7},
#  {'source_id': 'Lucien François Montaggioni',
#   'target_id': 'Bertrand Martin-Garin',
#   'strength': 7},
#  {'source_id': 'Elise Van Campo', 'target_id': 'Nick Marriner', 'strength': 7},
#  ...]

# %% [raw]
# from itertools import combinations
#
#
# def persons_links(patents):
#     links = {}
#     for patent in patents:
#         applicants = patent.get("applicants", [])
#         inventors = patent.get("inventors", [])
#
#         persons = list(
#             set([applicant.get("name") for applicant in applicants + inventors if applicant.get("type") == "person"])
#         )
#         co_persons = [tuple(sorted(combination)) for combination in combinations(persons, 2)]
#
#         for co_element in co_persons:
#             link_id = "---".join(co_element)
#             source_id = co_element[0]
#             target_id = co_element[1]
#
#             if link_id not in links:
#                 links[link_id] = {"source_id": source_id, "target_id": target_id, "strength": 1}
#             else:
#                 links[link_id]["strength"] += 1
#     return links
#
#
# def organizations_links(patents):
#     links = {}
#     for patent in patents:
#         applicants = patent.get("applicants", [])
#
#         organizations = list(
#             set([applicant.get("name") for applicant in applicants if applicant.get("type") == "organisation"])
#         )
#         co_organizations = [tuple(sorted(combination)) for combination in combinations(organizations, 2)]
#
#         for co_element in co_organizations:
#             link_id = "---".join(co_element)
#             source_id = co_element[0]
#             target_id = co_element[1]
#
#             if link_id not in links:
#                 links[link_id] = {"source_id": source_id, "target_id": target_id, "strength": 1}
#             else:
#                 links[link_id]["strength"] += 1
#     return links
#
#
# def cpc_links(patents, group="ss_classe"):
#     links = {}
#     for patent in patents:
#         cpcs = patent.get("cpc", {}).get(group, [])
#         cpcs = [f'{cpc.get("code")}###{cpc.get("label")}' for cpc in cpcs]
#         co_cpc = [tuple(sorted(combinations)) for combinations in combinations(cpcs, 2)]
#
#         for co_element in co_cpc:
#             link_id = "---".join(co_element)
#             source_name = co_element[0].split("###")[1]
#             target_name = co_element[1].split("###")[1]
#
#             if link_id not in links:
#                 links[link_id] = {"source_id": source_name, "target_id": target_name, "strength": 1}
#             else:
#                 links[link_id]["strength"] += 1
#
#     return links

# %%
df = pd.DataFrame(links)
df.to_json("teds_ipcc_authors.json", orient="records")
