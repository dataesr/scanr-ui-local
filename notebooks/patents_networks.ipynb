# %%
import os
import requests
import pandas as pd
from dotenv import load_dotenv

# %%
load_dotenv("../client/.env.local")
# Out:
# True

# %%
scanr_url = "https://cluster-production.elasticsearch.dataesr.ovh/scanr-patents/_search"
scanr_key = f'Basic {os.getenv("VITE_API_KEY")}'
scanr_headers = {"Authorization": scanr_key}

source_fields = ["id", "inpadocFamily", "applicants", "inventors", "title", "cpc", "year"]


def scanr_patents(size=10, query=None):
    body = {
        "size": size,
        "_source": source_fields,
        "query": {
            "bool": {
                "must": [
                    {
                        "query_string": {"query": query or "*"},
                    },
                ],
            },
        },
    }

    res = requests.post(scanr_url, json=body, headers=scanr_headers)
    if res.status_code == 200:
        return res.json()
    else:
        print(f"error {res.status_code}: {res.reason}")
        print(res.text)
        return None

# %%
res = scanr_patents(query="biodiversity")
res
# Out:
# {'took': 4634,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 7, 'relation': 'eq'},
#   'max_score': 14.744541,
#   'hits': [{'_index': 'scanr-patents-20240530',
#     '_id': 'cHimyI8BZJJbNSwJ5oC0',
#     '_score': 14.744541,
#     '_ignored': ['summary.en.keyword'],
#     '_source': {'id': '44243408',
#      'inpadocFamily': '332873297',
#      'applicants': [{'name': 'Beynet Jean Marc',
#        'type': 'person',
#        'country': 'FR'},
#       {'name': 'Brl Ingenierie',
#        'type': 'organisation',
#        'country': 'FR',
#        'ids': [{'id': '391484862', 'type': 'siren'}]},
#       {'name': 'Fraysse Nicolas', 'type': 'person', 'country': 'FR'},
#       {'name': 'De Monbrison David', 'type': 'person', 'country': 'FR'},
#       {'name': "Le Groupement D'Interet Scientifique Gis Posidonie",
#        'type': 'organisation',
#        'country': 'FR',
#        'ids': [{'id': '338863699', 'type': 'siren'}]}],
#      'inventors': [],
#      'title': {'fr': '',
#       'en': 'Artificial, modular, evolutionary, habitual device for use in aquatic environment to provide e.g. shelter for flora, has elementary module arranged in cells of support, and including reliefs favorizing development of biodiversity',
#       'default': ''},
#      'cpc': {'groupe': [{'code': 'A01K61/70',
#         'label': 'Culture of aquatic animals - Artificial fishing banks or reefs'},
#        {'code': 'Y02A40/81',
#         'label': 'Adaptation technologies in agriculture, forestry, livestock or agroalimentary production - in fisheries management'},
#        {'code': 'A01K61/00', 'label': 'Culture of aquatic animals'}],
#       'ss_classe': [{'code': 'A01K',
#         'label': 'ANIMAL HUSBANDRY CARE OF BIRDS, FISHES, INSECTS FISHING REARING OR BREEDING ANIMALS, NOT OTHERWISE PROVIDED FOR NEW BREEDS OF ANIMALS'},
#        {'code': 'Y02A',
#         'label': 'TECHNOLOGIES FOR ADAPTATION TO CLIMATE CHANGE'}],
#       'classe': [{'code': 'A01',
#         'label': 'AGRICULTURE FORESTRY ANIMAL HUSBANDRY HUNTING TRAPPING FISHING'},
#        {'code': 'Y02',
#         'label': 'TECHNOLOGIES OR APPLICATIONS FOR MITIGATION OR ADAPTATION AGAINST CLIMATE CHANGE'}],
#       'section': [{'code': 'A', 'label': 'HUMAN NECESSITIES'},
#        {'code': 'Y',
#         'label': 'GENERAL TAGGING OF NEW TECHNOLOGICAL DEVELOPMENTS GENERAL TAGGING OF CROSS-SECTIONAL TECHNOLOGIES SPANNING OVER SEVERAL SECTIONS OF THE IPC TECHNICAL SUBJECTS COVERED BY FORMER USPC CROSS-REFERENCE ART COLLECTIONS [XRACs] AND DIGESTS'}]},
#      'year': 2010,
#      'denormalized_structures': [{'id': '391484862',
#        'mainAddress': {'address': '1105 Av Pdt Pierre Mendes France',
#         'gps': {'lat': 43.821226, 'lon': 4.385379},
#         'postcode': '30000',
#         'city': 'Nîmes',
#         'localisationSuggestions': ['Occitanie',
#          'Nîmes (agglomération)',
#          'Nîmes',
#          'Montpellier (académie)',
#          'Gard (30)'],
#         'country': 'France'},
#        'kind': ['Secteur privé'],
#        'label': {'fr': 'B.R.L. INGENIERIE', 'default': 'B.R.L. INGENIERIE'},
#        'acronym': {'fr': 'BRL I', 'default': 'BRL I'},
#        'status': 'active',
#        'isFrench': True},
#       {'id': '338863699',
#        'mainAddress': {'gps': {'lat': 43.232667, 'lon': 5.435833},
#         'postcode': '13009',
#         'city': 'Marseille',
#         'localisationSuggestions': ["Provence-Alpes-Côte d'Azur",
#          'Marseille - Aix-en-Provence (agglomération)',
#          'Marseille  9e',
#          'Aix-Marseille (académie)',
#          'Bouches-du-Rhône (13)'],
#         'country': 'France'},
#        'label': {'fr': 'GIS POSIDONIE', 'default': 'GIS POSIDONIE'},
#        'status': 'active',
#        'isFrench': True}]}},
#    {'_index': 'scanr-patents-20240530',
#     '_id': 'HauuyI8BoKO6HjItDzcc',
#     '_score': 14.744541,
#     '_ignored': ['summary.fr.keyword', 'summary.en.keyword'],
#     '_source': {'id': '78820900',
#      'inpadocFamily': '562378993',
#      'applicants': [{'name': 'Thorel Jean Noel',
#        'type': 'person',
#        'country': 'FR'},
#       {'name': 'Thorel Jean-Noël', 'type': 'person', 'country': 'FR'},
#       {'name': 'NAOS INSTITUTE OF LIFE SCIENCE',
#        'type': 'organisation',
#        'country': 'FR',
#        'ids': [{'id': '820613446', 'type': 'siren'}]}],
#      'inventors': [],
#      'title': {'fr': 'METHODE DE CRIBLAGE D’INGREDIENTS ET DE COMPOSITIONS TOPIQUES ECOBIOLOGIQUES, ET SON UTILISATION POUR REALISER UN SOIN COSMETIQUE DE RESTAURATION DU MICROBIOTE CUTANE',
#       'en': 'METHOD FOR SELECTING ECOBIOLOGICAL TOPICAL COMPOSITIONS AND INGREDIENTS CAPABLE OF RESTORING OR REINFORCING THE SKIN MICROBIOTA',
#       'default': ''},
#      'cpc': {'groupe': [{'code': 'A61K8/19',
#         'label': 'Cosmetics or similar toiletry preparations - characterised by the composition'},
#        {'code': 'A61K8/466',
#         'label': 'Cosmetics or similar toiletry preparations - characterised by the composition'},
#        {'code': 'A61K8/4946',
#         'label': 'Cosmetics or similar toiletry preparations - characterised by the composition'},
#        {'code': 'A61K8/60',
#         'label': 'Cosmetics or similar toiletry preparations - characterised by the composition'},
#        {'code': 'A61K8/645',
#         'label': 'Cosmetics or similar toiletry preparations - characterised by the composition'},
#        {'code': 'A61K8/735',
#         'label': 'Cosmetics or similar toiletry preparations - characterised by the composition'},
#        {'code': 'A61K8/99',
#         'label': 'Cosmetics or similar toiletry preparations - characterised by the composition'},
#        {'code': 'A61K31/047',
#         'label': 'Medicinal preparations containing organic active ingredients - Hydroxy compounds, e.g. alcohols Salts thereof, e.g. alcoholates'},
#        {'code': 'A61K31/205',
#         'label': 'Medicinal preparations containing organic active ingredients - Acids Anhydrides, halides or salts thereof, e.g. sulfur acids, imidic, hydrazonic or\xa0hydroximic acids'},
#        {'code': 'A61K31/4172',
#         'label': 'Medicinal preparations containing organic active ingredients - Heterocyclic compounds'},
#        {'code': 'A61K31/7016',
#         'label': 'Medicinal preparations containing organic active ingredients - Carbohydrates Sugars Derivatives thereof'},
#        {'code': 'A61K45/06',
#         'label': 'Medicinal preparations containing active ingredients not provided for in groups A61K31/00\xa0-\xa0A61K41/00 - Mixtures of active ingredients without chemical characterisation, e.g. antiphlogistics and cardiaca'},
#        {'code': 'A61K2800/522', 'label': 'non disponible'},
#        {'code': 'A61P17/00', 'label': 'Drugs for dermatological disorders'},
#        {'code': 'A61Q19/10',
#         'label': 'Preparations for care of the skin - Washing or bathing preparations'},
#        {'code': 'C12Q1/025',
#         'label': 'Measuring or testing processes involving enzymes, nucleic acids or microorganisms Compositions therefor Processes of preparing such compositions - involving viable microorganisms'},
#        {'code': 'C12Q1/06',
#         'label': 'Measuring or testing processes involving enzymes, nucleic acids or microorganisms Compositions therefor Processes of preparing such compositions - involving viable microorganisms'},
#        {'code': 'C12Q1/689',
#         'label': 'Measuring or testing processes involving enzymes, nucleic acids or microorganisms Compositions therefor Processes of preparing such compositions - involving nucleic acids'},
#        {'code': 'C40B30/06',
#         'label': 'Methods of screening libraries - by measuring effects on living organisms, tissues or cells'},
#        {'code': 'A61K8/18',
#         'label': 'Cosmetics or similar toiletry preparations - characterised by the composition'},
#        {'code': 'A61K31/00',
#         'label': 'Medicinal preparations containing organic active ingredients'},
#        {'code': 'A61K33/00',
#         'label': 'Medicinal preparations containing inorganic active ingredients'},
#        {'code': 'A61Q19/00', 'label': 'Preparations for care of the skin'},
#        {'code': 'C12Q1/68',
#         'label': 'Measuring or testing processes involving enzymes, nucleic acids or microorganisms Compositions therefor Processes of preparing such compositions - involving nucleic acids'},
#        {'code': 'C12Q1/6806',
#         'label': 'Measuring or testing processes involving enzymes, nucleic acids or microorganisms Compositions therefor Processes of preparing such compositions - involving nucleic acids'},
#        {'code': 'C12Q1/6869',
#         'label': 'Measuring or testing processes involving enzymes, nucleic acids or microorganisms Compositions therefor Processes of preparing such compositions - involving nucleic acids'},
#        {'code': 'C12Q1/6888',
#         'label': 'Measuring or testing processes involving enzymes, nucleic acids or microorganisms Compositions therefor Processes of preparing such compositions - involving nucleic acids'},
#        {'code': 'C12Q1/02',
#         'label': 'Measuring or testing processes involving enzymes, nucleic acids or microorganisms Compositions therefor Processes of preparing such compositions - involving viable microorganisms'}],
#       'ss_classe': [{'code': 'A61K',
#         'label': 'PREPARATIONS FOR MEDICAL, DENTAL OR TOILETRY PURPOSES'},
#        {'code': 'A61P',
#         'label': 'SPECIFIC THERAPEUTIC ACTIVITY OF CHEMICAL COMPOUNDS OR MEDICINAL PREPARATIONS'},
#        {'code': 'A61Q',
#         'label': 'SPECIFIC USE OF COSMETICS OR SIMILAR TOILETRY PREPARATIONS'},
#        {'code': 'C12Q',
#         'label': 'MEASURING OR TESTING PROCESSES INVOLVING ENZYMES, NUCLEIC ACIDS OR MICROORGANISMS COMPOSITIONS OR TEST PAPERS THEREFOR PROCESSES OF PREPARING SUCH COMPOSITIONS CONDITION-RESPONSIVE CONTROL IN MICROBIOLOGICAL OR ENZYMOLOGICAL PROCESSES'},
#        {'code': 'C40B',
#         'label': 'COMBINATORIAL CHEMISTRY LIBRARIES, e.g. CHEMICAL LIBRARIES'}],
#       'classe': [{'code': 'A61',
#         'label': 'MEDICAL OR VETERINARY SCIENCE HYGIENE'},
#        {'code': 'C12',
#         'label': 'BIOCHEMISTRY BEER SPIRITS WINE VINEGAR MICROBIOLOGY ENZYMOLOGY MUTATION OR GENETIC ENGINEERING'},
#        {'code': 'C40', 'label': 'COMBINATORIAL TECHNOLOGY'}],
#       'section': [{'code': 'A', 'label': 'HUMAN NECESSITIES'},
#        {'code': 'C', 'label': 'CHEMISTRY METALLURGY'}]},
#      'year': 2021,
#      'denormalized_structures': [{'id': '820613446',
#        'mainAddress': {'address': '355 Rue Pierre Simon Laplace',
#         'gps': {'lat': 43.476553, 'lon': 5.379009},
#         'postcode': '13290',
#         'city': 'Aix-en-Provence',
#         'localisationSuggestions': ["Provence-Alpes-Côte d'Azur",
#          'Marseille - Aix-en-Provence (agglomération)',
#          'Aix-en-Provence',
#          'Aix-Marseille (académie)',
#          'Bouches-du-Rhône (13)'],
#         'country': 'France'},
#        'kind': ['Secteur privé'],
#        'label': {'fr': 'NAOS INSTITUTE OF LIFE SCIENCE',
#         'default': 'NAOS INSTITUTE OF LIFE SCIENCE'},
#        'acronym': {'fr': 'NAOS ILS', 'default': 'NAOS ILS'},
#        'status': 'active',
#        'isFrench': True}]}},
#    {'_index': 'scanr-patents-20240530',
#     '_id': 'qKutyI8BoKO6HjItxSCc',
#     '_score': 13.60792,
#     '_ignored': ['summary.fr.keyword', 'summary.en.keyword'],
#     '_source': {'id': '75690487',
#      'inpadocFamily': '549968343',
#      'applicants': [{'name': 'Vion Peter', 'type': 'person', 'country': 'FR'},
#       {'name': 'PUBERT HENRI SAS',
#        'type': 'organisation',
#        'country': 'FR',
#        'ids': [{'id': '547050542', 'type': 'siren'}]}],
#      'inventors': [{'name': 'Gerbaud Nicolas',
#        'country': 'FR',
#        'type': 'person'},
#       {'name': 'Gerbaud Nicolas', 'country': 'FR', 'type': 'person'}],
#      'title': {'fr': 'ENGIN MOTORISE DESTINE AU TRAVAIL DE LA TERRE RESPECTUEUX DE LA BIODIVERSITE',
#       'en': 'MOTORISED MACHINE FOR BIODIVERSITY-FRIENDLY GROUND CULTIVATION',
#       'default': ''},
#      'cpc': {'groupe': [{'code': 'A01B1/065',
#         'label': 'Hand tools - Hoes Hand cultivators'},
#        {'code': 'A01B33/06',
#         'label': 'Tilling implements with rotary driven tools - with tools on vertical or steeply-inclined shaft'},
#        {'code': 'A01B35/16',
#         'label': 'Other machines for working soil - with rotating or circulating non-propelled tools'},
#        {'code': 'A01B1/06', 'label': 'Hand tools - Hoes Hand cultivators'}],
#       'ss_classe': [{'code': 'A01B',
#         'label': 'SOIL WORKING IN AGRICULTURE OR FORESTRY PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL'}],
#       'classe': [{'code': 'A01',
#         'label': 'AGRICULTURE FORESTRY ANIMAL HUSBANDRY HUNTING TRAPPING FISHING'}],
#       'section': [{'code': 'A', 'label': 'HUMAN NECESSITIES'}]},
#      'year': 2021,
#      'denormalized_structures': [{'id': '547050542',
#        'mainAddress': {'gps': {'lat': 46.697669, 'lon': -1.039413},
#         'postcode': '85110',
#         'city': 'Chantonnay',
#         'localisationSuggestions': ['Pays de la Loire',
#          'Chantonnay (agglomération)',
#          'Chantonnay',
#          'Nantes (académie)',
#          'Vendée (85)'],
#         'country': 'France'},
#        'kind': ['Secteur privé'],
#        'label': {'fr': 'PUBERT HENRI SAS', 'default': 'PUBERT HENRI SAS'},
#        'status': 'active',
#        'isFrench': True}]}},
#    {'_index': 'scanr-patents-20240530',
#     '_id': '96qoyI8BoKO6HjItcV7f',
#     '_score': 11.842648,
#     '_ignored': ['summary.en.keyword'],
#     '_source': {'id': '48570212',
#      'inpadocFamily': '407078752',
#      'applicants': [{'name': 'Hydrocity',
#        'type': 'organisation',
#        'country': 'FR',
#        'ids': [{'id': '790255574', 'type': 'siren'}]}],
#      'inventors': [{'name': 'Villemagne Florent',
#        'country': 'FR',
#        'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'}],
#      'title': {'fr': '',
#       'en': 'Installation, useful for recycling water for buildings with sources of gray wastewater resulting from e.g. washing of hands, comprises network of pipes, purification module, ecological units, sanitation unit, and hydraulic unit',
#       'default': ''},
#      'cpc': {'groupe': [{'code': 'E03B1/041',
#         'label': 'Methods or layout of installations for water supply - for domestic or like local supply'},
#        {'code': 'E03B3/02',
#         'label': 'Methods or installations for obtaining or collecting drinking water or tap water - from rain-water'},
#        {'code': 'Y02A20/108',
#         'label': 'Water conservation Efficient water supply Efficient water use - Rainwater harvesting'},
#        {'code': 'Y02A20/30',
#         'label': 'Water conservation Efficient water supply Efficient water use - Relating to industrial water supply, e.g. used for cooling'},
#        {'code': 'C02F3/32',
#         'label': 'Biological treatment of water, waste water, or sewage - characterised by the animals or plants used, e.g. algae'},
#        {'code': 'E03B3/03',
#         'label': 'Methods or installations for obtaining or collecting drinking water or tap water - from rain-water'}],
#       'ss_classe': [{'code': 'E03B',
#         'label': 'INSTALLATIONS OR METHODS FOR OBTAINING, COLLECTING, OR DISTRIBUTING WATER'},
#        {'code': 'Y02A',
#         'label': 'TECHNOLOGIES FOR ADAPTATION TO CLIMATE CHANGE'},
#        {'code': 'C02F',
#         'label': 'TREATMENT OF WATER, WASTE WATER, SEWAGE, OR SLUDGE'}],
#       'classe': [{'code': 'E03', 'label': 'WATER SUPPLY SEWERAGE'},
#        {'code': 'Y02',
#         'label': 'TECHNOLOGIES OR APPLICATIONS FOR MITIGATION OR ADAPTATION AGAINST CLIMATE CHANGE'},
#        {'code': 'C02',
#         'label': 'TREATMENT OF WATER, WASTE WATER, SEWAGE, OR SLUDGE'}],
#       'section': [{'code': 'E', 'label': 'FIXED CONSTRUCTIONS'},
#        {'code': 'Y',
#         'label': 'GENERAL TAGGING OF NEW TECHNOLOGICAL DEVELOPMENTS GENERAL TAGGING OF CROSS-SECTIONAL TECHNOLOGIES SPANNING OVER SEVERAL SECTIONS OF THE IPC TECHNICAL SUBJECTS COVERED BY FORMER USPC CROSS-REFERENCE ART COLLECTIONS [XRACs] AND DIGESTS'},
#        {'code': 'C', 'label': 'CHEMISTRY METALLURGY'}]},
#      'year': 2013,
#      'denormalized_structures': [{'id': '790255574',
#        'mainAddress': {'address': '11 bis Rue de la Frébardière',
#         'gps': {'lat': 48.1014, 'lon': -1.628817},
#         'postcode': '35510',
#         'city': 'Cesson-Sévigné',
#         'localisationSuggestions': ['Bretagne',
#          'Rennes (agglomération)',
#          'Cesson-Sévigné',
#          'Rennes (académie)',
#          'Ille-et-Vilaine (35)'],
#         'country': 'France'},
#        'kind': ['Secteur privé'],
#        'label': {'fr': 'HYDROCITY', 'default': 'HYDROCITY'},
#        'status': 'active',
#        'isFrench': True}]}},
#    {'_index': 'scanr-patents-20240530',
#     '_id': 'gnWpyI8BqgRIMCR9l2B-',
#     '_score': 11.535863,
#     '_ignored': ['summary.fr.keyword', 'summary.en.keyword'],
#     '_source': {'id': '52102932',
#      'inpadocFamily': '424838376',
#      'applicants': [{'name': 'Egis Eau',
#        'type': 'organisation',
#        'country': 'FR',
#        'ids': [{'id': '493378038', 'type': 'siren'}]}],
#      'inventors': [{'name': 'Villemagne Florent',
#        'country': 'FR',
#        'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'}],
#      'title': {'fr': "ELEMENT POUR LE DEVELOPPEMENT DE LA FAUNE OU DE LA FLORE AQUATIQUE, ET DISPOSITIF D'HABITAT ARTIFICIEL COMPRENANT AU MOINS UN TEL ELEMENT",
#       'en': 'ELEMENT FOR DEVELOPING AQUATIC FAUNA AND FLORA, AND MAN-MADE HABITAT DEVICE COMPRISING AT LEAST ONE SUCH ELEMENT',
#       'default': ''},
#      'cpc': {'groupe': [{'code': 'A01K61/73',
#         'label': 'Culture of aquatic animals - Artificial fishing banks or reefs'},
#        {'code': 'E02B3/043',
#         'label': 'Engineering works in connection with control or use of streams, rivers, coasts, or other marine sites Sealings or joints for engineering works in general - Structures or apparatus for, or methods of, protecting banks, coasts, or harbours'},
#        {'code': 'Y02A40/81',
#         'label': 'Adaptation technologies in agriculture, forestry, livestock or agroalimentary production - in fisheries management'},
#        {'code': 'A01K61/00', 'label': 'Culture of aquatic animals'},
#        {'code': 'E02B3/04',
#         'label': 'Engineering works in connection with control or use of streams, rivers, coasts, or other marine sites Sealings or joints for engineering works in general - Structures or apparatus for, or methods of, protecting banks, coasts, or harbours'}],
#       'ss_classe': [{'code': 'A01K',
#         'label': 'ANIMAL HUSBANDRY CARE OF BIRDS, FISHES, INSECTS FISHING REARING OR BREEDING ANIMALS, NOT OTHERWISE PROVIDED FOR NEW BREEDS OF ANIMALS'},
#        {'code': 'E02B', 'label': 'HYDRAULIC ENGINEERING'},
#        {'code': 'Y02A',
#         'label': 'TECHNOLOGIES FOR ADAPTATION TO CLIMATE CHANGE'}],
#       'classe': [{'code': 'A01',
#         'label': 'AGRICULTURE FORESTRY ANIMAL HUSBANDRY HUNTING TRAPPING FISHING'},
#        {'code': 'E02',
#         'label': 'HYDRAULIC ENGINEERING FOUNDATIONS SOIL SHIFTING'},
#        {'code': 'Y02',
#         'label': 'TECHNOLOGIES OR APPLICATIONS FOR MITIGATION OR ADAPTATION AGAINST CLIMATE CHANGE'}],
#       'section': [{'code': 'A', 'label': 'HUMAN NECESSITIES'},
#        {'code': 'E', 'label': 'FIXED CONSTRUCTIONS'},
#        {'code': 'Y',
#         'label': 'GENERAL TAGGING OF NEW TECHNOLOGICAL DEVELOPMENTS GENERAL TAGGING OF CROSS-SECTIONAL TECHNOLOGIES SPANNING OVER SEVERAL SECTIONS OF THE IPC TECHNICAL SUBJECTS COVERED BY FORMER USPC CROSS-REFERENCE ART COLLECTIONS [XRACs] AND DIGESTS'}]},
#      'year': 2014,
#      'denormalized_structures': [{'id': '493378038',
#        'mainAddress': {'address': '889 Rue de la Vieille Poste',
#         'gps': {'lat': 43.614916, 'lon': 3.9080079999999997},
#         'postcode': '34000',
#         'city': 'Montpellier',
#         'localisationSuggestions': ['Occitanie',
#          'Montpellier (agglomération)',
#          'Montpellier',
#          'Montpellier (académie)',
#          'Hérault (34)'],
#         'country': 'France'},
#        'kind': ['Secteur privé'],
#        'label': {'fr': 'EGIS EAU SA', 'default': 'EGIS EAU SA'},
#        'status': 'active',
#        'isFrench': True}]}},
#    {'_index': 'scanr-patents-20240530',
#     '_id': 'DnipyI8BZJJbNSwJccVp',
#     '_score': 11.021882,
#     '_ignored': ['summary.en.keyword'],
#     '_source': {'id': '51787002',
#      'inpadocFamily': '423085264',
#      'applicants': [{'name': 'Université de Tours',
#        'type': 'organisation',
#        'country': 'FR',
#        'ids': [{'id': 'cqkij', 'type': 'id_paysage'},
#         {'id': '193708005', 'type': 'siren'}]}],
#      'inventors': [{'name': 'Munier Damien',
#        'country': 'FR',
#        'type': 'person'},
#       {'name': 'Venturini Gilles', 'country': 'FR', 'type': 'person'},
#       {'name': 'Arnault Ingrid', 'country': 'FR', 'type': 'person'},
#       {'name': 'Dalino Fabienne', 'country': 'FR', 'type': 'person'},
#       {'name': 'Arnault Ingrid', 'country': 'FR', 'type': 'person'},
#       {'name': 'Munier Damien', 'country': 'FR', 'type': 'person'},
#       {'name': 'Venturini Gilles', 'country': 'FR', 'type': 'person'},
#       {'name': 'Dalino Fabienne', 'country': 'FR', 'type': 'person'}],
#      'title': {'fr': 'METHODE DE CLASSIFICATION ET D’IDENTIFICATION DE MORPHOESPECES',
#       'en': 'METHOD FOR CLASSIFICATION AND IDENTIFICATION OF MORPHOLOGICAL SPECIES',
#       'default': ''},
#      'cpc': {'groupe': [{'code': 'G06V20/52',
#         'label': 'Scenes Scene-specific elements - Context or environment of the image'},
#        {'code': 'G06F19/14', 'label': 'non disponible'},
#        {'code': 'G16B10/00',
#         'label': 'ICT specially adapted for evolutionary bioinformatics, e.g. phylogenetic tree construction or analysis'},
#        {'code': 'G06K9/00', 'label': 'non disponible'}],
#       'ss_classe': [{'code': 'G06V',
#         'label': 'IMAGE OR VIDEO RECOGNITION OR UNDERSTANDING'},
#        {'code': 'G06F', 'label': 'ELECTRIC DIGITAL DATA PROCESSING'},
#        {'code': 'G16B',
#         'label': 'BIOINFORMATICS, i.e. INFORMATION AND COMMUNICATION TECHNOLOGY [ICT] SPECIALLY ADAPTED FOR GENETIC OR PROTEIN-RELATED DATA PROCESSING IN COMPUTATIONAL MOLECULAR BIOLOGY'},
#        {'code': 'G06K',
#         'label': 'GRAPHICAL DATA READING PRESENTATION OF DATA RECORD CARRIERS HANDLING RECORD CARRIERS'}],
#       'classe': [{'code': 'G06', 'label': 'COMPUTING CALCULATING OR COUNTING'},
#        {'code': 'G16',
#         'label': 'INFORMATION AND COMMUNICATION TECHNOLOGY [ICT] SPECIALLY ADAPTED FOR SPECIFIC APPLICATION FIELDS'}],
#       'section': [{'code': 'G', 'label': 'PHYSICS'}]},
#      'year': 2014,
#      'denormalized_structures': [{'id': 'cqkij'},
#       {'id': '193708005',
#        'mainAddress': {'address': "60 Rue du Plat d'Etain",
#         'gps': {'lat': 47.384108, 'lon': 0.6750149999999999},
#         'postcode': '37000',
#         'city': 'Tours',
#         'localisationSuggestions': ['Centre-Val de Loire',
#          'Tours (agglomération)',
#          'Tours',
#          'Orléans-Tours (académie)',
#          'Indre-et-Loire (37)'],
#         'country': 'France'},
#        'kind': ['Secteur public'],
#        'label': {'fr': 'Université de Tours',
#         'default': 'Université de Tours'},
#        'status': 'active',
#        'isFrench': True}]}},
#    {'_index': 'scanr-patents-20240530',
#     '_id': 'caqpyI8BoKO6HjItEXhQ',
#     '_score': 10.013849,
#     '_ignored': ['summary.fr.keyword', 'summary.en.keyword'],
#     '_source': {'id': '50473531',
#      'inpadocFamily': '416956019',
#      'applicants': [{'name': 'Charabot',
#        'type': 'organisation',
#        'country': 'FR',
#        'ids': [{'id': '415650217', 'type': 'siren'}]}],
#      'inventors': [{'name': 'Villemagne Florent',
#        'country': 'FR',
#        'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#       {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'}],
#      'title': {'fr': "PROCEDE DE PRODUCTION DE LACTONES A PARTIR D'UNE SOUCHE D'AUREOBASIDIUM PULLULANS",
#       'en': 'METHOD FOR PRODUCING LACTONES FROM A STRAIN OF AUREOBASIDIUM PULLULANS',
#       'default': ''},
#      'cpc': {'groupe': [{'code': 'C12P7/6409',
#         'label': 'Preparation of oxygen-containing organic compounds - Fats Fatty oils Ester-type waxes Higher fatty acids, i.e. having at least seven carbon atoms in an unbroken chain bound to a carboxyl group Oxidised oils or fats'},
#        {'code': 'C12P17/06',
#         'label': 'Preparation of heterocyclic carbon compounds with only O, N, S, Se or Te as ring hetero atoms - Oxygen as only ring hetero atoms'},
#        {'code': 'C12R1/645', 'label': 'Microorganisms - Fungi'},
#        {'code': 'C12P7/64',
#         'label': 'Preparation of oxygen-containing organic compounds - Fats Fatty oils Ester-type waxes Higher fatty acids, i.e. having at least seven carbon atoms in an unbroken chain bound to a carboxyl group Oxidised oils or fats'}],
#       'ss_classe': [{'code': 'C12P',
#         'label': 'FERMENTATION OR ENZYME-USING PROCESSES TO SYNTHESISE A DESIRED CHEMICAL COMPOUND OR COMPOSITION OR TO SEPARATE OPTICAL ISOMERS FROM A RACEMIC MIXTURE'},
#        {'code': 'C12R',
#         'label': 'INDEXING SCHEME ASSOCIATED WITH SUBCLASSES C12C - C12Q, RELATING TO MICROORGANISMS'}],
#       'classe': [{'code': 'C12',
#         'label': 'BIOCHEMISTRY BEER SPIRITS WINE VINEGAR MICROBIOLOGY ENZYMOLOGY MUTATION OR GENETIC ENGINEERING'}],
#       'section': [{'code': 'C', 'label': 'CHEMISTRY METALLURGY'}]},
#      'year': 2014,
#      'denormalized_structures': [{'id': '415650217',
#        'mainAddress': {'address': '10 Avenue Yves Emmanuel Baudoin',
#         'gps': {'lat': 43.658255, 'lon': 6.919718},
#         'postcode': '06130',
#         'city': 'Grasse',
#         'localisationSuggestions': ["Provence-Alpes-Côte d'Azur",
#          'Nice (agglomération)',
#          'Grasse',
#          'Nice (académie)',
#          'Alpes-Maritimes (06)'],
#         'country': 'France'},
#        'kind': ['Secteur privé'],
#        'label': {'fr': 'SOC CHARABOT SA', 'default': 'SOC CHARABOT SA'},
#        'acronym': {'fr': 'CC', 'default': 'CC'},
#        'status': 'old',
#        'isFrench': True}]}}]}}

# %%
patents = [patent.get("_source") for patent in res.get("hits").get("hits")]
patents
# Out:
# [{'id': '44243408',
#   'inpadocFamily': '332873297',
#   'applicants': [{'name': 'Beynet Jean Marc',
#     'type': 'person',
#     'country': 'FR'},
#    {'name': 'Brl Ingenierie',
#     'type': 'organisation',
#     'country': 'FR',
#     'ids': [{'id': '391484862', 'type': 'siren'}]},
#    {'name': 'Fraysse Nicolas', 'type': 'person', 'country': 'FR'},
#    {'name': 'De Monbrison David', 'type': 'person', 'country': 'FR'},
#    {'name': "Le Groupement D'Interet Scientifique Gis Posidonie",
#     'type': 'organisation',
#     'country': 'FR',
#     'ids': [{'id': '338863699', 'type': 'siren'}]}],
#   'inventors': [],
#   'title': {'fr': '',
#    'en': 'Artificial, modular, evolutionary, habitual device for use in aquatic environment to provide e.g. shelter for flora, has elementary module arranged in cells of support, and including reliefs favorizing development of biodiversity',
#    'default': ''},
#   'cpc': {'groupe': [{'code': 'A01K61/70',
#      'label': 'Culture of aquatic animals - Artificial fishing banks or reefs'},
#     {'code': 'Y02A40/81',
#      'label': 'Adaptation technologies in agriculture, forestry, livestock or agroalimentary production - in fisheries management'},
#     {'code': 'A01K61/00', 'label': 'Culture of aquatic animals'}],
#    'ss_classe': [{'code': 'A01K',
#      'label': 'ANIMAL HUSBANDRY CARE OF BIRDS, FISHES, INSECTS FISHING REARING OR BREEDING ANIMALS, NOT OTHERWISE PROVIDED FOR NEW BREEDS OF ANIMALS'},
#     {'code': 'Y02A',
#      'label': 'TECHNOLOGIES FOR ADAPTATION TO CLIMATE CHANGE'}],
#    'classe': [{'code': 'A01',
#      'label': 'AGRICULTURE FORESTRY ANIMAL HUSBANDRY HUNTING TRAPPING FISHING'},
#     {'code': 'Y02',
#      'label': 'TECHNOLOGIES OR APPLICATIONS FOR MITIGATION OR ADAPTATION AGAINST CLIMATE CHANGE'}],
#    'section': [{'code': 'A', 'label': 'HUMAN NECESSITIES'},
#     {'code': 'Y',
#      'label': 'GENERAL TAGGING OF NEW TECHNOLOGICAL DEVELOPMENTS GENERAL TAGGING OF CROSS-SECTIONAL TECHNOLOGIES SPANNING OVER SEVERAL SECTIONS OF THE IPC TECHNICAL SUBJECTS COVERED BY FORMER USPC CROSS-REFERENCE ART COLLECTIONS [XRACs] AND DIGESTS'}]},
#   'year': 2010,
#   'denormalized_structures': [{'id': '391484862',
#     'mainAddress': {'address': '1105 Av Pdt Pierre Mendes France',
#      'gps': {'lat': 43.821226, 'lon': 4.385379},
#      'postcode': '30000',
#      'city': 'Nîmes',
#      'localisationSuggestions': ['Occitanie',
#       'Nîmes (agglomération)',
#       'Nîmes',
#       'Montpellier (académie)',
#       'Gard (30)'],
#      'country': 'France'},
#     'kind': ['Secteur privé'],
#     'label': {'fr': 'B.R.L. INGENIERIE', 'default': 'B.R.L. INGENIERIE'},
#     'acronym': {'fr': 'BRL I', 'default': 'BRL I'},
#     'status': 'active',
#     'isFrench': True},
#    {'id': '338863699',
#     'mainAddress': {'gps': {'lat': 43.232667, 'lon': 5.435833},
#      'postcode': '13009',
#      'city': 'Marseille',
#      'localisationSuggestions': ["Provence-Alpes-Côte d'Azur",
#       'Marseille - Aix-en-Provence (agglomération)',
#       'Marseille  9e',
#       'Aix-Marseille (académie)',
#       'Bouches-du-Rhône (13)'],
#      'country': 'France'},
#     'label': {'fr': 'GIS POSIDONIE', 'default': 'GIS POSIDONIE'},
#     'status': 'active',
#     'isFrench': True}]},
#  {'id': '78820900',
#   'inpadocFamily': '562378993',
#   'applicants': [{'name': 'Thorel Jean Noel',
#     'type': 'person',
#     'country': 'FR'},
#    {'name': 'Thorel Jean-Noël', 'type': 'person', 'country': 'FR'},
#    {'name': 'NAOS INSTITUTE OF LIFE SCIENCE',
#     'type': 'organisation',
#     'country': 'FR',
#     'ids': [{'id': '820613446', 'type': 'siren'}]}],
#   'inventors': [],
#   'title': {'fr': 'METHODE DE CRIBLAGE D’INGREDIENTS ET DE COMPOSITIONS TOPIQUES ECOBIOLOGIQUES, ET SON UTILISATION POUR REALISER UN SOIN COSMETIQUE DE RESTAURATION DU MICROBIOTE CUTANE',
#    'en': 'METHOD FOR SELECTING ECOBIOLOGICAL TOPICAL COMPOSITIONS AND INGREDIENTS CAPABLE OF RESTORING OR REINFORCING THE SKIN MICROBIOTA',
#    'default': ''},
#   'cpc': {'groupe': [{'code': 'A61K8/19',
#      'label': 'Cosmetics or similar toiletry preparations - characterised by the composition'},
#     {'code': 'A61K8/466',
#      'label': 'Cosmetics or similar toiletry preparations - characterised by the composition'},
#     {'code': 'A61K8/4946',
#      'label': 'Cosmetics or similar toiletry preparations - characterised by the composition'},
#     {'code': 'A61K8/60',
#      'label': 'Cosmetics or similar toiletry preparations - characterised by the composition'},
#     {'code': 'A61K8/645',
#      'label': 'Cosmetics or similar toiletry preparations - characterised by the composition'},
#     {'code': 'A61K8/735',
#      'label': 'Cosmetics or similar toiletry preparations - characterised by the composition'},
#     {'code': 'A61K8/99',
#      'label': 'Cosmetics or similar toiletry preparations - characterised by the composition'},
#     {'code': 'A61K31/047',
#      'label': 'Medicinal preparations containing organic active ingredients - Hydroxy compounds, e.g. alcohols Salts thereof, e.g. alcoholates'},
#     {'code': 'A61K31/205',
#      'label': 'Medicinal preparations containing organic active ingredients - Acids Anhydrides, halides or salts thereof, e.g. sulfur acids, imidic, hydrazonic or\xa0hydroximic acids'},
#     {'code': 'A61K31/4172',
#      'label': 'Medicinal preparations containing organic active ingredients - Heterocyclic compounds'},
#     {'code': 'A61K31/7016',
#      'label': 'Medicinal preparations containing organic active ingredients - Carbohydrates Sugars Derivatives thereof'},
#     {'code': 'A61K45/06',
#      'label': 'Medicinal preparations containing active ingredients not provided for in groups A61K31/00\xa0-\xa0A61K41/00 - Mixtures of active ingredients without chemical characterisation, e.g. antiphlogistics and cardiaca'},
#     {'code': 'A61K2800/522', 'label': 'non disponible'},
#     {'code': 'A61P17/00', 'label': 'Drugs for dermatological disorders'},
#     {'code': 'A61Q19/10',
#      'label': 'Preparations for care of the skin - Washing or bathing preparations'},
#     {'code': 'C12Q1/025',
#      'label': 'Measuring or testing processes involving enzymes, nucleic acids or microorganisms Compositions therefor Processes of preparing such compositions - involving viable microorganisms'},
#     {'code': 'C12Q1/06',
#      'label': 'Measuring or testing processes involving enzymes, nucleic acids or microorganisms Compositions therefor Processes of preparing such compositions - involving viable microorganisms'},
#     {'code': 'C12Q1/689',
#      'label': 'Measuring or testing processes involving enzymes, nucleic acids or microorganisms Compositions therefor Processes of preparing such compositions - involving nucleic acids'},
#     {'code': 'C40B30/06',
#      'label': 'Methods of screening libraries - by measuring effects on living organisms, tissues or cells'},
#     {'code': 'A61K8/18',
#      'label': 'Cosmetics or similar toiletry preparations - characterised by the composition'},
#     {'code': 'A61K31/00',
#      'label': 'Medicinal preparations containing organic active ingredients'},
#     {'code': 'A61K33/00',
#      'label': 'Medicinal preparations containing inorganic active ingredients'},
#     {'code': 'A61Q19/00', 'label': 'Preparations for care of the skin'},
#     {'code': 'C12Q1/68',
#      'label': 'Measuring or testing processes involving enzymes, nucleic acids or microorganisms Compositions therefor Processes of preparing such compositions - involving nucleic acids'},
#     {'code': 'C12Q1/6806',
#      'label': 'Measuring or testing processes involving enzymes, nucleic acids or microorganisms Compositions therefor Processes of preparing such compositions - involving nucleic acids'},
#     {'code': 'C12Q1/6869',
#      'label': 'Measuring or testing processes involving enzymes, nucleic acids or microorganisms Compositions therefor Processes of preparing such compositions - involving nucleic acids'},
#     {'code': 'C12Q1/6888',
#      'label': 'Measuring or testing processes involving enzymes, nucleic acids or microorganisms Compositions therefor Processes of preparing such compositions - involving nucleic acids'},
#     {'code': 'C12Q1/02',
#      'label': 'Measuring or testing processes involving enzymes, nucleic acids or microorganisms Compositions therefor Processes of preparing such compositions - involving viable microorganisms'}],
#    'ss_classe': [{'code': 'A61K',
#      'label': 'PREPARATIONS FOR MEDICAL, DENTAL OR TOILETRY PURPOSES'},
#     {'code': 'A61P',
#      'label': 'SPECIFIC THERAPEUTIC ACTIVITY OF CHEMICAL COMPOUNDS OR MEDICINAL PREPARATIONS'},
#     {'code': 'A61Q',
#      'label': 'SPECIFIC USE OF COSMETICS OR SIMILAR TOILETRY PREPARATIONS'},
#     {'code': 'C12Q',
#      'label': 'MEASURING OR TESTING PROCESSES INVOLVING ENZYMES, NUCLEIC ACIDS OR MICROORGANISMS COMPOSITIONS OR TEST PAPERS THEREFOR PROCESSES OF PREPARING SUCH COMPOSITIONS CONDITION-RESPONSIVE CONTROL IN MICROBIOLOGICAL OR ENZYMOLOGICAL PROCESSES'},
#     {'code': 'C40B',
#      'label': 'COMBINATORIAL CHEMISTRY LIBRARIES, e.g. CHEMICAL LIBRARIES'}],
#    'classe': [{'code': 'A61',
#      'label': 'MEDICAL OR VETERINARY SCIENCE HYGIENE'},
#     {'code': 'C12',
#      'label': 'BIOCHEMISTRY BEER SPIRITS WINE VINEGAR MICROBIOLOGY ENZYMOLOGY MUTATION OR GENETIC ENGINEERING'},
#     {'code': 'C40', 'label': 'COMBINATORIAL TECHNOLOGY'}],
#    'section': [{'code': 'A', 'label': 'HUMAN NECESSITIES'},
#     {'code': 'C', 'label': 'CHEMISTRY METALLURGY'}]},
#   'year': 2021,
#   'denormalized_structures': [{'id': '820613446',
#     'mainAddress': {'address': '355 Rue Pierre Simon Laplace',
#      'gps': {'lat': 43.476553, 'lon': 5.379009},
#      'postcode': '13290',
#      'city': 'Aix-en-Provence',
#      'localisationSuggestions': ["Provence-Alpes-Côte d'Azur",
#       'Marseille - Aix-en-Provence (agglomération)',
#       'Aix-en-Provence',
#       'Aix-Marseille (académie)',
#       'Bouches-du-Rhône (13)'],
#      'country': 'France'},
#     'kind': ['Secteur privé'],
#     'label': {'fr': 'NAOS INSTITUTE OF LIFE SCIENCE',
#      'default': 'NAOS INSTITUTE OF LIFE SCIENCE'},
#     'acronym': {'fr': 'NAOS ILS', 'default': 'NAOS ILS'},
#     'status': 'active',
#     'isFrench': True}]},
#  {'id': '75690487',
#   'inpadocFamily': '549968343',
#   'applicants': [{'name': 'Vion Peter', 'type': 'person', 'country': 'FR'},
#    {'name': 'PUBERT HENRI SAS',
#     'type': 'organisation',
#     'country': 'FR',
#     'ids': [{'id': '547050542', 'type': 'siren'}]}],
#   'inventors': [{'name': 'Gerbaud Nicolas', 'country': 'FR', 'type': 'person'},
#    {'name': 'Gerbaud Nicolas', 'country': 'FR', 'type': 'person'}],
#   'title': {'fr': 'ENGIN MOTORISE DESTINE AU TRAVAIL DE LA TERRE RESPECTUEUX DE LA BIODIVERSITE',
#    'en': 'MOTORISED MACHINE FOR BIODIVERSITY-FRIENDLY GROUND CULTIVATION',
#    'default': ''},
#   'cpc': {'groupe': [{'code': 'A01B1/065',
#      'label': 'Hand tools - Hoes Hand cultivators'},
#     {'code': 'A01B33/06',
#      'label': 'Tilling implements with rotary driven tools - with tools on vertical or steeply-inclined shaft'},
#     {'code': 'A01B35/16',
#      'label': 'Other machines for working soil - with rotating or circulating non-propelled tools'},
#     {'code': 'A01B1/06', 'label': 'Hand tools - Hoes Hand cultivators'}],
#    'ss_classe': [{'code': 'A01B',
#      'label': 'SOIL WORKING IN AGRICULTURE OR FORESTRY PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL'}],
#    'classe': [{'code': 'A01',
#      'label': 'AGRICULTURE FORESTRY ANIMAL HUSBANDRY HUNTING TRAPPING FISHING'}],
#    'section': [{'code': 'A', 'label': 'HUMAN NECESSITIES'}]},
#   'year': 2021,
#   'denormalized_structures': [{'id': '547050542',
#     'mainAddress': {'gps': {'lat': 46.697669, 'lon': -1.039413},
#      'postcode': '85110',
#      'city': 'Chantonnay',
#      'localisationSuggestions': ['Pays de la Loire',
#       'Chantonnay (agglomération)',
#       'Chantonnay',
#       'Nantes (académie)',
#       'Vendée (85)'],
#      'country': 'France'},
#     'kind': ['Secteur privé'],
#     'label': {'fr': 'PUBERT HENRI SAS', 'default': 'PUBERT HENRI SAS'},
#     'status': 'active',
#     'isFrench': True}]},
#  {'id': '48570212',
#   'inpadocFamily': '407078752',
#   'applicants': [{'name': 'Hydrocity',
#     'type': 'organisation',
#     'country': 'FR',
#     'ids': [{'id': '790255574', 'type': 'siren'}]}],
#   'inventors': [{'name': 'Villemagne Florent',
#     'country': 'FR',
#     'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'}],
#   'title': {'fr': '',
#    'en': 'Installation, useful for recycling water for buildings with sources of gray wastewater resulting from e.g. washing of hands, comprises network of pipes, purification module, ecological units, sanitation unit, and hydraulic unit',
#    'default': ''},
#   'cpc': {'groupe': [{'code': 'E03B1/041',
#      'label': 'Methods or layout of installations for water supply - for domestic or like local supply'},
#     {'code': 'E03B3/02',
#      'label': 'Methods or installations for obtaining or collecting drinking water or tap water - from rain-water'},
#     {'code': 'Y02A20/108',
#      'label': 'Water conservation Efficient water supply Efficient water use - Rainwater harvesting'},
#     {'code': 'Y02A20/30',
#      'label': 'Water conservation Efficient water supply Efficient water use - Relating to industrial water supply, e.g. used for cooling'},
#     {'code': 'C02F3/32',
#      'label': 'Biological treatment of water, waste water, or sewage - characterised by the animals or plants used, e.g. algae'},
#     {'code': 'E03B3/03',
#      'label': 'Methods or installations for obtaining or collecting drinking water or tap water - from rain-water'}],
#    'ss_classe': [{'code': 'E03B',
#      'label': 'INSTALLATIONS OR METHODS FOR OBTAINING, COLLECTING, OR DISTRIBUTING WATER'},
#     {'code': 'Y02A', 'label': 'TECHNOLOGIES FOR ADAPTATION TO CLIMATE CHANGE'},
#     {'code': 'C02F',
#      'label': 'TREATMENT OF WATER, WASTE WATER, SEWAGE, OR SLUDGE'}],
#    'classe': [{'code': 'E03', 'label': 'WATER SUPPLY SEWERAGE'},
#     {'code': 'Y02',
#      'label': 'TECHNOLOGIES OR APPLICATIONS FOR MITIGATION OR ADAPTATION AGAINST CLIMATE CHANGE'},
#     {'code': 'C02',
#      'label': 'TREATMENT OF WATER, WASTE WATER, SEWAGE, OR SLUDGE'}],
#    'section': [{'code': 'E', 'label': 'FIXED CONSTRUCTIONS'},
#     {'code': 'Y',
#      'label': 'GENERAL TAGGING OF NEW TECHNOLOGICAL DEVELOPMENTS GENERAL TAGGING OF CROSS-SECTIONAL TECHNOLOGIES SPANNING OVER SEVERAL SECTIONS OF THE IPC TECHNICAL SUBJECTS COVERED BY FORMER USPC CROSS-REFERENCE ART COLLECTIONS [XRACs] AND DIGESTS'},
#     {'code': 'C', 'label': 'CHEMISTRY METALLURGY'}]},
#   'year': 2013,
#   'denormalized_structures': [{'id': '790255574',
#     'mainAddress': {'address': '11 bis Rue de la Frébardière',
#      'gps': {'lat': 48.1014, 'lon': -1.628817},
#      'postcode': '35510',
#      'city': 'Cesson-Sévigné',
#      'localisationSuggestions': ['Bretagne',
#       'Rennes (agglomération)',
#       'Cesson-Sévigné',
#       'Rennes (académie)',
#       'Ille-et-Vilaine (35)'],
#      'country': 'France'},
#     'kind': ['Secteur privé'],
#     'label': {'fr': 'HYDROCITY', 'default': 'HYDROCITY'},
#     'status': 'active',
#     'isFrench': True}]},
#  {'id': '52102932',
#   'inpadocFamily': '424838376',
#   'applicants': [{'name': 'Egis Eau',
#     'type': 'organisation',
#     'country': 'FR',
#     'ids': [{'id': '493378038', 'type': 'siren'}]}],
#   'inventors': [{'name': 'Villemagne Florent',
#     'country': 'FR',
#     'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'}],
#   'title': {'fr': "ELEMENT POUR LE DEVELOPPEMENT DE LA FAUNE OU DE LA FLORE AQUATIQUE, ET DISPOSITIF D'HABITAT ARTIFICIEL COMPRENANT AU MOINS UN TEL ELEMENT",
#    'en': 'ELEMENT FOR DEVELOPING AQUATIC FAUNA AND FLORA, AND MAN-MADE HABITAT DEVICE COMPRISING AT LEAST ONE SUCH ELEMENT',
#    'default': ''},
#   'cpc': {'groupe': [{'code': 'A01K61/73',
#      'label': 'Culture of aquatic animals - Artificial fishing banks or reefs'},
#     {'code': 'E02B3/043',
#      'label': 'Engineering works in connection with control or use of streams, rivers, coasts, or other marine sites Sealings or joints for engineering works in general - Structures or apparatus for, or methods of, protecting banks, coasts, or harbours'},
#     {'code': 'Y02A40/81',
#      'label': 'Adaptation technologies in agriculture, forestry, livestock or agroalimentary production - in fisheries management'},
#     {'code': 'A01K61/00', 'label': 'Culture of aquatic animals'},
#     {'code': 'E02B3/04',
#      'label': 'Engineering works in connection with control or use of streams, rivers, coasts, or other marine sites Sealings or joints for engineering works in general - Structures or apparatus for, or methods of, protecting banks, coasts, or harbours'}],
#    'ss_classe': [{'code': 'A01K',
#      'label': 'ANIMAL HUSBANDRY CARE OF BIRDS, FISHES, INSECTS FISHING REARING OR BREEDING ANIMALS, NOT OTHERWISE PROVIDED FOR NEW BREEDS OF ANIMALS'},
#     {'code': 'E02B', 'label': 'HYDRAULIC ENGINEERING'},
#     {'code': 'Y02A',
#      'label': 'TECHNOLOGIES FOR ADAPTATION TO CLIMATE CHANGE'}],
#    'classe': [{'code': 'A01',
#      'label': 'AGRICULTURE FORESTRY ANIMAL HUSBANDRY HUNTING TRAPPING FISHING'},
#     {'code': 'E02',
#      'label': 'HYDRAULIC ENGINEERING FOUNDATIONS SOIL SHIFTING'},
#     {'code': 'Y02',
#      'label': 'TECHNOLOGIES OR APPLICATIONS FOR MITIGATION OR ADAPTATION AGAINST CLIMATE CHANGE'}],
#    'section': [{'code': 'A', 'label': 'HUMAN NECESSITIES'},
#     {'code': 'E', 'label': 'FIXED CONSTRUCTIONS'},
#     {'code': 'Y',
#      'label': 'GENERAL TAGGING OF NEW TECHNOLOGICAL DEVELOPMENTS GENERAL TAGGING OF CROSS-SECTIONAL TECHNOLOGIES SPANNING OVER SEVERAL SECTIONS OF THE IPC TECHNICAL SUBJECTS COVERED BY FORMER USPC CROSS-REFERENCE ART COLLECTIONS [XRACs] AND DIGESTS'}]},
#   'year': 2014,
#   'denormalized_structures': [{'id': '493378038',
#     'mainAddress': {'address': '889 Rue de la Vieille Poste',
#      'gps': {'lat': 43.614916, 'lon': 3.9080079999999997},
#      'postcode': '34000',
#      'city': 'Montpellier',
#      'localisationSuggestions': ['Occitanie',
#       'Montpellier (agglomération)',
#       'Montpellier',
#       'Montpellier (académie)',
#       'Hérault (34)'],
#      'country': 'France'},
#     'kind': ['Secteur privé'],
#     'label': {'fr': 'EGIS EAU SA', 'default': 'EGIS EAU SA'},
#     'status': 'active',
#     'isFrench': True}]},
#  {'id': '51787002',
#   'inpadocFamily': '423085264',
#   'applicants': [{'name': 'Université de Tours',
#     'type': 'organisation',
#     'country': 'FR',
#     'ids': [{'id': 'cqkij', 'type': 'id_paysage'},
#      {'id': '193708005', 'type': 'siren'}]}],
#   'inventors': [{'name': 'Munier Damien', 'country': 'FR', 'type': 'person'},
#    {'name': 'Venturini Gilles', 'country': 'FR', 'type': 'person'},
#    {'name': 'Arnault Ingrid', 'country': 'FR', 'type': 'person'},
#    {'name': 'Dalino Fabienne', 'country': 'FR', 'type': 'person'},
#    {'name': 'Arnault Ingrid', 'country': 'FR', 'type': 'person'},
#    {'name': 'Munier Damien', 'country': 'FR', 'type': 'person'},
#    {'name': 'Venturini Gilles', 'country': 'FR', 'type': 'person'},
#    {'name': 'Dalino Fabienne', 'country': 'FR', 'type': 'person'}],
#   'title': {'fr': 'METHODE DE CLASSIFICATION ET D’IDENTIFICATION DE MORPHOESPECES',
#    'en': 'METHOD FOR CLASSIFICATION AND IDENTIFICATION OF MORPHOLOGICAL SPECIES',
#    'default': ''},
#   'cpc': {'groupe': [{'code': 'G06V20/52',
#      'label': 'Scenes Scene-specific elements - Context or environment of the image'},
#     {'code': 'G06F19/14', 'label': 'non disponible'},
#     {'code': 'G16B10/00',
#      'label': 'ICT specially adapted for evolutionary bioinformatics, e.g. phylogenetic tree construction or analysis'},
#     {'code': 'G06K9/00', 'label': 'non disponible'}],
#    'ss_classe': [{'code': 'G06V',
#      'label': 'IMAGE OR VIDEO RECOGNITION OR UNDERSTANDING'},
#     {'code': 'G06F', 'label': 'ELECTRIC DIGITAL DATA PROCESSING'},
#     {'code': 'G16B',
#      'label': 'BIOINFORMATICS, i.e. INFORMATION AND COMMUNICATION TECHNOLOGY [ICT] SPECIALLY ADAPTED FOR GENETIC OR PROTEIN-RELATED DATA PROCESSING IN COMPUTATIONAL MOLECULAR BIOLOGY'},
#     {'code': 'G06K',
#      'label': 'GRAPHICAL DATA READING PRESENTATION OF DATA RECORD CARRIERS HANDLING RECORD CARRIERS'}],
#    'classe': [{'code': 'G06', 'label': 'COMPUTING CALCULATING OR COUNTING'},
#     {'code': 'G16',
#      'label': 'INFORMATION AND COMMUNICATION TECHNOLOGY [ICT] SPECIALLY ADAPTED FOR SPECIFIC APPLICATION FIELDS'}],
#    'section': [{'code': 'G', 'label': 'PHYSICS'}]},
#   'year': 2014,
#   'denormalized_structures': [{'id': 'cqkij'},
#    {'id': '193708005',
#     'mainAddress': {'address': "60 Rue du Plat d'Etain",
#      'gps': {'lat': 47.384108, 'lon': 0.6750149999999999},
#      'postcode': '37000',
#      'city': 'Tours',
#      'localisationSuggestions': ['Centre-Val de Loire',
#       'Tours (agglomération)',
#       'Tours',
#       'Orléans-Tours (académie)',
#       'Indre-et-Loire (37)'],
#      'country': 'France'},
#     'kind': ['Secteur public'],
#     'label': {'fr': 'Université de Tours', 'default': 'Université de Tours'},
#     'status': 'active',
#     'isFrench': True}]},
#  {'id': '50473531',
#   'inpadocFamily': '416956019',
#   'applicants': [{'name': 'Charabot',
#     'type': 'organisation',
#     'country': 'FR',
#     'ids': [{'id': '415650217', 'type': 'siren'}]}],
#   'inventors': [{'name': 'Villemagne Florent',
#     'country': 'FR',
#     'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'},
#    {'name': 'Villemagne Florent', 'country': 'FR', 'type': 'person'}],
#   'title': {'fr': "PROCEDE DE PRODUCTION DE LACTONES A PARTIR D'UNE SOUCHE D'AUREOBASIDIUM PULLULANS",
#    'en': 'METHOD FOR PRODUCING LACTONES FROM A STRAIN OF AUREOBASIDIUM PULLULANS',
#    'default': ''},
#   'cpc': {'groupe': [{'code': 'C12P7/6409',
#      'label': 'Preparation of oxygen-containing organic compounds - Fats Fatty oils Ester-type waxes Higher fatty acids, i.e. having at least seven carbon atoms in an unbroken chain bound to a carboxyl group Oxidised oils or fats'},
#     {'code': 'C12P17/06',
#      'label': 'Preparation of heterocyclic carbon compounds with only O, N, S, Se or Te as ring hetero atoms - Oxygen as only ring hetero atoms'},
#     {'code': 'C12R1/645', 'label': 'Microorganisms - Fungi'},
#     {'code': 'C12P7/64',
#      'label': 'Preparation of oxygen-containing organic compounds - Fats Fatty oils Ester-type waxes Higher fatty acids, i.e. having at least seven carbon atoms in an unbroken chain bound to a carboxyl group Oxidised oils or fats'}],
#    'ss_classe': [{'code': 'C12P',
#      'label': 'FERMENTATION OR ENZYME-USING PROCESSES TO SYNTHESISE A DESIRED CHEMICAL COMPOUND OR COMPOSITION OR TO SEPARATE OPTICAL ISOMERS FROM A RACEMIC MIXTURE'},
#     {'code': 'C12R',
#      'label': 'INDEXING SCHEME ASSOCIATED WITH SUBCLASSES C12C - C12Q, RELATING TO MICROORGANISMS'}],
#    'classe': [{'code': 'C12',
#      'label': 'BIOCHEMISTRY BEER SPIRITS WINE VINEGAR MICROBIOLOGY ENZYMOLOGY MUTATION OR GENETIC ENGINEERING'}],
#    'section': [{'code': 'C', 'label': 'CHEMISTRY METALLURGY'}]},
#   'year': 2014,
#   'denormalized_structures': [{'id': '415650217',
#     'mainAddress': {'address': '10 Avenue Yves Emmanuel Baudoin',
#      'gps': {'lat': 43.658255, 'lon': 6.919718},
#      'postcode': '06130',
#      'city': 'Grasse',
#      'localisationSuggestions': ["Provence-Alpes-Côte d'Azur",
#       'Nice (agglomération)',
#       'Grasse',
#       'Nice (académie)',
#       'Alpes-Maritimes (06)'],
#      'country': 'France'},
#     'kind': ['Secteur privé'],
#     'label': {'fr': 'SOC CHARABOT SA', 'default': 'SOC CHARABOT SA'},
#     'acronym': {'fr': 'CC', 'default': 'CC'},
#     'status': 'old',
#     'isFrench': True}]}]

# %%
from itertools import combinations


def persons_links(patents):
    links = {}
    for patent in patents:
        applicants = patent.get("applicants", [])
        inventors = patent.get("inventors", [])

        persons = list(
            set([applicant.get("name") for applicant in applicants + inventors if applicant.get("type") == "person"])
        )
        co_persons = [tuple(sorted(combination)) for combination in combinations(persons, 2)]

        for co_element in co_persons:
            link_id = "---".join(co_element)
            source_id = co_element[0]
            target_id = co_element[1]

            if link_id not in links:
                links[link_id] = {"source_id": source_id, "target_id": target_id, "strength": 1}
            else:
                links[link_id]["strength"] += 1
    return links


def organizations_links(patents):
    links = {}
    for patent in patents:
        applicants = patent.get("applicants", [])

        organizations = list(
            set([applicant.get("name") for applicant in applicants if applicant.get("type") == "organisation"])
        )
        co_organizations = [tuple(sorted(combination)) for combination in combinations(organizations, 2)]

        for co_element in co_organizations:
            link_id = "---".join(co_element)
            source_id = co_element[0]
            target_id = co_element[1]

            if link_id not in links:
                links[link_id] = {"source_id": source_id, "target_id": target_id, "strength": 1}
            else:
                links[link_id]["strength"] += 1
    return links


def cpc_ss_classe_links(patents):
    links = {}
    for patent in patents:
        ss_classes = patent.get("cpc", {}).get("ss_classe", [])
        ss_classes = [f'{classe.get("code")}###{classe.get("label")}' for classe in ss_classes]
        co_ss_classes = [tuple(sorted(combinations)) for combinations in combinations(ss_classes, 2)]

        for co_element in co_ss_classes:
            link_id = "---".join(co_element)
            source_name = co_element[0].split("###")[1]
            target_name = co_element[1].split("###")[1]

            if link_id not in links:
                links[link_id] = {"source_id": source_name, "target_id": target_name, "strength": 1}
            else:
                links[link_id]["strength"] += 1

    return links

# %%
persons_links(patents[0:2])
# Out:
# {'De Monbrison David---Fraysse Nicolas': {'source_id': 'De Monbrison David',
#   'target_id': 'Fraysse Nicolas',
#   'strength': 1},
#  'Beynet Jean Marc---Fraysse Nicolas': {'source_id': 'Beynet Jean Marc',
#   'target_id': 'Fraysse Nicolas',
#   'strength': 1},
#  'Beynet Jean Marc---De Monbrison David': {'source_id': 'Beynet Jean Marc',
#   'target_id': 'De Monbrison David',
#   'strength': 1},
#  'Thorel Jean Noel---Thorel Jean-Noël': {'source_id': 'Thorel Jean Noel',
#   'target_id': 'Thorel Jean-Noël',
#   'strength': 1}}

# %%
df = pd.DataFrame.from_dict(cpc_ss_classe_links(patents), orient="index")
df.to_json("patents_ss_classe_links.json", orient="records")
